# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\nv_wo\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\nv_wo\anaconda3\lib\site-packages (from selenium) (1.25.11)

# %%
#NECESSARY IMPORTS
import json
import pandas as pd
from selenium import webdriver

# %%
#Variables to determine the flow of the code
GET_FROM_API=True
EXPORT_JSON=True
SCRAP_SPANISH=True

# %%
#Function to print json objects in a more visual way
def jprint(obj):
    text = json.dumps(obj, sort_keys=False, indent=4, ensure_ascii=False)
    print(text)

# %% [markdown]
# ## Scraping Spanish platform

# %% [markdown]
# ## Projects

# %%
if (SCRAP_SPANISH):
    #Import the google chrome driver 
    driver= webdriver.Chrome('./chromedriver.exe')
    
    #go to the platform's webpage
    driver.get('https://ciencia-ciudadana.es/proyecto-cc/')
    
    #Get all the projects titles and links and store them in a list
    projects = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')

    projects_list=[]

    for project in projects:
        title=project.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
        link = title.get_attribute('href')

        #print(title.text)
        #print(link)

        this_project={"Title": title.text, "Link": link}
        projects_list.append(this_project)
    driver.close()

# %%
if (SCRAP_SPANISH):
    
    driver= webdriver.Chrome('./chromedriver.exe')
    
    #Create a list of dictionaries
    lista_diccionarios=[]

    #Iterate, for every project in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(projects_list)):
        project_dict={}

        driver.get(projects_list[i]["Link"])
        left_area=driver.find_element_by_xpath("//*[@id='left-area']")
        idd=left_area.find_element_by_xpath(".//*").get_attribute("id")

        project_area=left_area.find_element_by_xpath("//*/div[1]/h1")
        project_dict["id"]=idd
        project_dict["name"]=project_area.text
        project_dict["type"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[3]").text
        project_dict["aim"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[1]").text
        project_dict["subtitle"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[2]").text
        project_dict["description"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[2]").text
        project_dict["keywords"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[4]").text
        project_dict["start_date"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[1]/div[2]/div[1]").text
        project_dict["end_date"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[1]/div[2]/div[2]").text
        project_dict["url"]=projects_list[i]["Link"]
        project_dict["mainOrganisation"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[1]").text
        project_dict["responsibleEntity"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[3]").text
        project_dict["province"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[1]/div[2]/div[4]").text
        project_dict["howToParticipate"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[6]").text
        project_dict["equipment"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[7]").text
        project_dict["public"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[1]/div[2]/div[3]").text
        project_dict["participants"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[1]/div[2]/div[5]").text
        project_dict["fundingTeam"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[4]").text
        project_dict["moreEntities"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[5]/div[5]").text
        project_dict["results_summary"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[7]/div[1]").text
        project_dict["results_link"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[7]/div[2]").text
        project_dict["impact"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[7]/div[3]").text
        project_dict["impact_examples"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[7]/div[4]").text
        project_dict["motivation"]=left_area.find_element_by_xpath("//*/div[2]/div/div/div[2]/div[9]/div").text

        lista_diccionarios.append(project_dict)
    driver.close()
    
    print("Number of projects: ",len(projects_list))
    jprint(lista_diccionarios)
# Out:
# Number of projects:  295
# [
#     {
#         "id": "post-13125",
#         "name": "Ríos y riveras libres de plástico. Biodiversidad.",
#         "type": "institución de ciencia ciudadana",
#         "aim": "Pretendemos acercar y sensibilizar a la población y a la ciudadanía , fundamentalmente las personas que viven en el Espacio Natural Sierra Norte. Conocer e interpretar el medio natural y hacer acciones que faciliten la mejora ambiental y el comportamiento de las personas que visitan disfrutan de su tiempo libre.",
#         "subtitle": "Programa de participación y sensibilización Ambiental en el Parque Natural Sierra Norte de Sevilla.",
#         "description": "Diseño y desarrollo de proyectos educativos, ambientales, de participación social y de divulgación de la ciencia, que puedan contribuir a mejorar el entorno (natural y social) y el mundo en el que vivimos.",
#         "keywords": "Biodiversidad, Ecología y Medioambiente, Gestión de Recursos Naturales, Naturaleza y Aire Libre",
#         "start_date": "22 de mayo de 2021",
#         "end_date": "15 de mayo de 2023",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/rios-y-riveras-libres-de-plastico-biodiversidad/",
#         "mainOrganisation": "Rios Y Riveras Libres De Plástico. Argos Proyectos Educativos",
#         "responsibleEntity": "Consejería de Agricultura, Ganadería, Pesca y Desarrollo Sostenible de la Junta de Andalucía.",
#         "province": "Sevilla",
#         "howToParticipate": "Colaborando y facilitando datos en momentos determinados.",
#         "equipment": "Cámara de fotos, ...",
#         "public": "Adultos (entre 18 y 65 años)",
#         "participants": "10 a 100 personas",
#         "fundingTeam": "Argos Proyectos Educativos S.L .\nTrinidad Herrero Campo. Coordinadora del Proyecto.\nJosechu Ferreras Tome.\nPilar Estada Aceña.\nGuadalupe Jiménez Leira.\nAna Velázquez Perejon\nJose Maria Jiménez Solis",
#         "moreEntities": "Asociaciones, Ayuntamientos, voluntariado, Consejería de Agricultura, Ganadería, Pesca y Desarrollo Sostenible de la Junta de Andalucía.",
#         "results_summary": "",
#         "results_link": "",
#         "impact": "científico, social, educativo, medioambiental",
#         "impact_examples": "",
#         "motivation": "Por divulgar la investigación de personas que participan"
#     },
#     {
#         "id": "post-13118",
#         "name": "urban Butterfly Monitor Scheme – Observatorio ciudadano de mariposas urbanas en Madrid y Barcelona",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "El Observatorio ciudadano de mariposas urbanas uBMS nace en 2018 como una red colaborativa de voluntarios que aúnan esfuerzos para obtener datos sobre las poblaciones de mariposas en las ciudades de Barcelona y Madrid, y desde el 2021 también en la ciudad de Sabadell. Así se obtendrán datos relevantes para evaluar y entender la biodiversidad urbana, y con ello herramientas de gestión que fomenten su aumento en nuestras ciudades. El uBMS se une a la red internacional de Programas de Seguimiento de Mariposas (abreviados BMS, del inglés Butterfly Monitoring Schemes), vigente en más de 25 países, entre ellos el programa BMS España y el catalán CBMS. El objetivo general es obtener datos mensuales de presencia y abundancia de las especies presentes en las ciudades de Barcelona y Madrid para entender la ecología de las especies en los medios urbanos a lo largo de los años. Los objetivos específicos: Conocer la diversidad de mariposas en nuestras ciudades y su evolución a lo largo del tiempo Crear un indicador de calidad de biodiversidad urbana Entender que características de la ciudad fomentan la biodiversidad y cuales la limitan Proporcionar recomendaciones de gestión de los jardines y su entorno para favorecer la biodiversidad en las ciudades",
#         "subtitle": "bservatorio ciudadano de mariposas urbanas, uBMS. WEB: http://ubms.creaf.cat/",
#         "description": "El uBMS se une a la red internacional de Programas de Seguimiento de Mariposas (abreviados BMS, del inglés Butterfly Monitoring Schemes) actualmente vigente en más de 25 países, entre ellos el programa español BMS España y el catalán CBMS. La idea se inició en Reino Unido, siendo éste el primer país en desarrollar un esquema de seguimiento de mariposas en 1970. La idea se extendió al resto de Europa a partir de la década de los noventa En España, el primer programa de seguimiento se inició en Catalunya (CBMS) en 1994, posteriormente surgiendo otras iniciativas unidas actualmente en el programa de seguimiento nacional (BMS España) y, en paralelo, los seguimientos de la asociación Zerynthia.\nEl objetivo de todos ellos, al igual que el de otros programas similares de seguimientos de fauna, es obtener información sobre abundancia y presencia de las especies para conocer sus cambios poblacionales (p. ej. aumentos y disminuciones de abundancia) y los posibles factores asociados a estos cambios. En muchos casos esta información tiene aplicaciones en la gestión y conservación de mariposas.\nJunto al cambio climático, el crecimiento de las áreas urbanas es uno de los cambios ambientales más importantes a los que la conservación se enfrenta. A raíz de esto, recientemente ha nacido un nuevo interés por conocer y entender la biodiversidad de nuestras ciudades y así, en paralelo, fomentar un diseño de ciudad con potencial para albergar especies nativas a través de la mejora y creación de jardines y zonas urbanas verdes. Es por ello que el uBMS cuenta con el apoyo de los Ayuntamientos de Madrid y Barcelona.\nLas mariposas diurnas, además de ser insectos polinizadores y un grupo estéticamente atractivo, reúnen una serie de características que les convierte en excelentes indicadores de biodiversidad. Eso significa que podemos extrapolar en cierta medida el estado de sus poblaciones, los cambios en la riqueza y abundancia de sus especies y las causas asociadas a otras especies más difíciles de observar y/o identificar.\nEl observatorio es una iniciativa del CREAF en colaboración con el Museu de Granollers, la Universidad Complutense de Madrid y la Universidad Autónoma de Madrid. Cuenta con el apoyo de iniciativas similares como el Grupo de Seguimiento de Fauna (Universidad Complutense de Madrid), los programas de seguimiento de mariposas catalán CBMS y español BMS España y el proyecto europeo Butterfly Conservation Europe. Cuenta con el apoyo de la Fundación Biodiversidad del Ministerio de Agricultura y Pesca, Alimentación y Medio Ambiente, y con la ayuda de los ayuntamientos de Madrid y Barcelona.\nDesde el año 2021, el observatorio también cuenta con la colaboración de la asociación ADENC y el equipo de Replantegem, para la realización del proyecto en la ciudad de Sabadell (Barcelona).",
#         "keywords": "Animales, Biodiversidad, Ecología y Medioambiente, Insectos y Polinizadores, Seguimiento de Especies a largo plazo",
#         "start_date": "1 de enero de 2018",
#         "end_date": "31 de mayo de 2081",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/urban-butterfly-monitor-scheme-observatorio-ciudadano-de-mariposas-urbanas-en-madrid-y-barcelona/",
#         "mainOrganisation": "Urban Butterfly Monitor Scheme (CREAF)",
#         "responsibleEntity": "CREAF",
#         "province": "Barcelona, Madrid, Sabadell.",
#         "howToParticipate": "Los voluntarios del uBMS realizan una visita cada quince días de marzo a finales de octubre a uno o más parques seccionados en Madrid, Barcelona o Sabadell durante las cuales identifican y cuentan las especies de mariposas que observan. Cada voluntario tiene asignado uno o más parques según su elección, en el cual realiza el conteo de mariposas a lo largo de un transecto de 300m y un paseo libre de duración determinada en función del tamaño del parque. Detalles completos en: http://ubms.creaf.cat/participa/",
#         "equipment": "Guía de mariposas, se les proporciona una guía por ciudad con trucos para identificar las especies, ficha de campo (imprimible desde la web), lápiz, cazamariposas (no obligatorio), carnet identificativo de voluntario .",
#         "public": "Todo tipo de público",
#         "participants": "10 a 100 personas",
#         "fundingTeam": "Dra. Yolanda Melero. Investigadora Postdoctoral y Investigadora Principal del Proyecto (CREAF).\nDr. Joan Pino. Catedrático (Universidad Autónoma de Barcelona; CREAF)\nDr. Paco Cabrero. Profesor Titular (Universidad Complutense de Madrid)\nDr. Constantí Stefanescu. Investigador (Museu Granollers),\nDr. Miguel Munguira. Profesor Titular (Universidad Autónoma de Madrid)\nDr. Enrique García-Barros (Universidad Autónoma de Madrid)",
#         "moreEntities": "El observatorio es una iniciativa del CREAF en colaboración con el Museu de Granollers, la Universidad Complutense de Madrid y la Universidad Autónoma de Madrid. Cuenta con el apoyo del Grupo de Seguimiento de Fauna (Universidad Complutense de Madrid), los programas de seguimiento de mariposas catalán CBMS y español BMS España y el proyecto europeo Butterfly Conservation Europe. Financiado inicialmente por la Fundación Biodiversidad del Ministerio de Transición Ecológica y actualmente por el Ayuntamiento de Barcelona.\nDesde el año 2021, el observatorio también cuenta con la colaboración de la asociación ADENC y el equipo de Replantegem,",
#         "results_summary": "",
#         "results_link": "http://ubms.creaf.cat/resultados/",
#         "impact": "científico, social, educativo, medioambiental",
#         "impact_examples": "Se trabaja con los respectivos ayuntamientos en la mejora y creación de zonas verdes en las ciudades. Por ej: https://ajuntament.barcelona.cat/ecologiaurbana/es/que-hacemos-y-porque/verde-urbano-y-biodiversidad/plan-infraestructura-verde",
#         "motivation": "La sociedad entiendo mejor la ciencia, su utilidad y se hace más partícipe en los problemas sociales y medioambientales que nos rodean dándoles responsabilidad en el cambio."
#     },
#     {
#         "id": "post-13110",
#         "name": "AGEO",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "La Plataforma para la gestión de Riesgos geológicos en el Atlántico (AGEO) tiene como objetivo poner en marcha 5 pilotos de Observatorios Ciudadanos en 5 países europeos sobre riesgos geológicos en la región atlántica. AGEO está siendo desarrollada en consorcio con la Universidad de Lisboa como asociado principal y numerosos asociados adicionales de Portugal, España, Francia, Irlanda y el Reino Unido. AGEO es un proyecto financiado por el programa Interreg Espacio Atlántico, bajo la prioridad 3: fortalecer la resiliencia del territorio frente a los riesgos de origen natural, climático y humano",
#         "subtitle": "AGEO ATLANTIC Platform for Atlantic Geohazard Risk Management",
#         "description": "El piloto en España se va a desarrollar en las Islas Canarias, y supone la implementación de un Observatorio Ciudadano sobre desprendimiento de rocas y sus desencadenantes. El Observatorio Ciudadano busca probar nuevas formas de cooperación entre sociedad civil y autoridades locales, y demostrar cómo la participación de los ciudadanos en la prevención de los riesgos geológicos puede fortalecer los sistemas nacionales de riesgos. Se basa en la ciencia ciudadana donde los ciudadanos contribuyen activamente a la ciencia, adquiriendo nuevas habilidades y mejorando sus conocimientos.",
#         "keywords": "Geología y Ciencias de la Tierra",
#         "start_date": "1 de abril de 2021",
#         "end_date": "31 de diciembre de 2022",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/ageo/",
#         "mainOrganisation": "AGEO ATLANTIC",
#         "responsibleEntity": "Instituto Geológico y Minero de España",
#         "province": "Las Palmas de Gran Canaria",
#         "howToParticipate": "Utilizando la app de reportes de desprendimientos en su zona https://survey123.arcgis.com/share/6da844ad9e4a4e6ebc701d084591e6ec?open=menu\ny también la encuesta de riesgos https://survey123.arcgis.com/share/2299fdd2edd84f13b135171ff15688a4?open=menu",
#         "equipment": "Cualquier dispositivo digital",
#         "public": "Todo tipo de público",
#         "participants": "100 a 1.000 personas",
#         "fundingTeam": "VIC Vivero de Iniciativas Ciudadanas está encargada del Observatorio Ciudadano de las Islas Canarias.\nhttps://storymaps.arcgis.com/stories/2c978ee2f0b6465eb1d350fb0e37ffb2",
#         "moreEntities": "AGEO está siendo desarrollada en consorcio con la Universidad de Lisboa como asociado principal y doce asociados más de cinco países europeos (España, Francia, Irlanda, Portugal y Reino Unido), entre los que se encuentran la Asociación Portuguesa de Geólogos, Cerema, Instituto Geológico y Minero de España, La Palma Research Centre, Universidad de La Laguna, El Laboratorio Nacional de Energía y Geología, el Laboratorio Nacional de Ingenieria civil portugués, el British Geological Survey, la Universidad de Bretaña Occidental, la Universidad de Madeira, el University College en Dublin y la Cámara Municipal de Lisboa.",
#         "results_summary": "La Plataforma para la gestión de Riesgos geológicos en el Atlántico (AGEO por sus siglas en inglés) tiene como objetivo poner en marcha varios pilotos de Observatorios Ciudadanos sobre riesgos geológicos de acuerdo con las prioridades regionales para demostrar cómo la participación de los ciudadanos en la prevención de los riesgos geológicos puede fortalecer los sistemas nacionales de riesgos.\nLa región atlántica está expuesta a una serie de eventos de baja probabilidad y alto impacto y diversos escenarios de riesgo, que, debido a la baja probabilidad de ocurrencia y/o el alto coste de la acción mitigadora, carecen del nivel de preparación necesario para un seguimiento y una respuesta eficaces. AGEO tiene como objetivo probar una nueva forma de cooperación entre sociedad civil y autoridades locales para la creación de una respuesta local a los riesgos geológicos y fomentar el uso local de productos y servicios innovadores de observación de la Tierra proporcionados por las infraestructuras de datos europeas, en particular Copérnico. El proyecto fomentará un uso más eficiente de datos, productos y servicios de Copérnico a nivel regional.\nAGEO de involucrará con las comunidades locales para participar activamente en la preparación y el seguimiento de riesgos, e incorporar las capacidades locales en los sistemas de gestión de riesgos. Las experiencias adquiridas durante la puesta en marcha de los pilotos del Observatorio Ciudadano se utilizarán para formular recomendaciones para la creación de futuros observatorios en respuesta a la más amplia gama de peligros (tanto naturales como inducidos por el ser humano) en la región atlántica.\nLos Observatorios Ciudadanos se basan en la ciencia ciudadana, que se refiere a la participación del público general en actividades de investigación científica donde los ciudadanos contribuyen activamente a la ciencia, ya sea con su esfuerzo intelectual, su conocimiento del medio o con sus herramientas y recursos. Los participantes proporcionarán datos experimentales e infraestructuras para los investigadores, presentan nuevas preguntas y colaboran a la creación de la cultura científica. Los voluntarios también adquieren nuevas habilidades y mejoran sus conocimientos del trabajo científico de una manera atractiva. Como resultado de este escenario transdisciplinar y abierto se mejoran las interacciones entre la política, la sociedad y la ciencia creando una capacidad de decisión basada en la investigación democrática y las pruebas empíricas.\nPara ello se está trabajando en una aplicación móvil que permita recibir información de la ciudadanía para generar una red en la que se puedan aportar datos que sirven para enriquecer el estudio científico y que prevenga los riesgos de derrumbe asociados con fenómenos naturales como la lluvia, el viento o los movimientos sísmicos. La aplicación, que está en desarrollo, se podrá usar por todos los ciudadanos, aunque previamente se testará con las tres localidades seleccionadas en las Islas Canarias.",
#         "results_link": "www.ageoatlantic.eu\nwww.atlanticaera.eu\nhttps://www.copernicus.eu/es",
#         "impact": "científico, social",
#         "impact_examples": "https://www.facebook.com/ageoatlantic/\nhttps://www.canarias7.es/canarias/el-hierro/igme-elige-canarias-20210421123559-nt.html\nhttps://www.interempresas.net/ObrasPublicas/Articulos/325100-gestion-riesgos-geologicos-Area-Atlantica-dentro-del-programa-europeo-Interreg-AGEO.html\nhttps://www.ull.es/portal/noticias/2020/presentacion-proyecto-ageo/",
#         "motivation": "Empoderamoento social"
#     },
#     {
#         "id": "post-13040",
#         "name": "#FakeNurses",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "¿Alguna vez has buscado Enfermera en internet? Si lo has hecho ¿crees que la Enfermería es eso? Yo sí lo he buscado y desde luego que #EsaNoSoyYo. En la última década la Enfermería, como profesional del Cuidado, ha conseguido muchos avances pero éstos no se han traducido en la imagen que los medios de comunicación proyectan sobre ella (cofia, minifalda, sólo mujeres vocacionales, etc), perpetuando una percepción social de la Enfermería injusta y obsoleta. Esto tiene consecuencias en el trato que recibimos como profesionales (contratos precarios, salario menor con respecto a otros profesionales del mismo nivel formativo, techos de cristal, menos acceso a los puestos de liderazgo, etc) y es necesario cambiarlo... ¿será porque el cuidado, históricamente, es algo realizado por mujeres? Para cambiar un problema, primero hay que visibilizarlo y medirlo. Con este proyecto de Ciencia Ciudadana pretendemos sensibilizar a la población, detectar y analizar lo que hemos llamado #FakeNurses. Con esta información crearemos una Guía de Estilo de la Enfermería dirigida a los profesionales de la comunicación.",
#         "subtitle": "Por una imagen social justa de la Enfermería",
#         "description": "Las fases del proyecto son las siguientes:\n1. SENSIBILIZACIÓN: Realizaremos diversas acciones para visibilizar, informar y concienciar de la existencia de este problema a enfermeras/os, ciudadanía, profesionales de la comunicación e instituciones.\n2. RECOGIDA DE DATOS: ¡Aquí es donde tú puedes participar activamente! Observa los medios de comunicación, redes sociales... en tu entorno, y haznos llegar todo aquello que consideres que no representa de una manera justa y actual a la Enfermería: https://www.fuden.es/investigacion-divulgacion/fakenurses/\n3. ANÁLISIS DE DATOS: El equipo investigador de Fuden analizará vuestras aportaciones y redactará la Guía de Estilo de la Enfermería para los profesionales de la comunicación.\n4. DIFUSIÓN: La Fundación para el Desarrollo de la Enfermería, realizará diversas acciones para hacer llegar esta Guía a personas e instituciones clave.\nPero...¿Qué son los #FakeNurses?\nhttps://www.youtube.com/watch?v=BfbsFcPH9ZM\n#FakeNurses es un juego de palabras que conjuga Fake News (o bulos existentes sobre un tema) con la Enfermería. Se puede definir como toda información, visual, escrita o verbal que no proyecta una imagen completa, justa y actual de la enfermería. También se incluye aquella información reduccionista sobre nuestra actividad, como por ejemplo, que una enfermera sólo pincha, o sólo reparte medicación, obviando que las/os enfermeras/os también estamos en colegios, cárceles, empresas, ONGs, campamentos... en cualquier lugar que halla personas, nuestra razón de ser.\nNunca subestimes tu habilidad para mejorar la vida de alguien. ¡Anímate y participa!",
#         "keywords": "Ciencias Políticas, Ciencias Sociales, Educación, Medicina y Salud",
#         "start_date": "12 de mayo de 2021",
#         "end_date": "12 de mayo de 2022",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/fakenurses/",
#         "mainOrganisation": "Fundación Para El Desarrollo De La Enfermería, FUDEN",
#         "responsibleEntity": "Unidad de Cultura Científica y de la Innovación Fundación para el Desarrollo de la Enfermería. Departamento Investigación Fundación para el Desarrollo de la Enfermería",
#         "province": "Madrid",
#         "howToParticipate": "La participación es muy sencilla.\nPaso 1: Observa tu entorno y busca imágenes o narrativas sobre la Enfermería.\nPaso 2: Pregúntate ¿Esto es justo para un/a enfermero/a? (imagen sexista, sumisa, no profesional, despectiva...)\nPaso 3: Hazlo viral, compártelo en Redes Sociales, Whatsapp...\nPaso 4: Notifícanoslo a través de este formulario: https://www.fuden.es/investigacion-divulgacion/fakenurses/\n¡Bravo, has hecho Ciencia a la vez que una buena acción!",
#         "equipment": "Solo necesitarás un dispositivo electrónico con acceso a internet para compartirlo en Redes Sociales y enviarnos los #FakeNurses. https://www.fuden.es/investigacion-divulgacion/fakenurses/",
#         "public": "Todo tipo de público",
#         "participants": "100 a 1.000 personas",
#         "fundingTeam": "Equipo investigador:\nDra. Mª Nélida Conejo Pérez. Directora Departamento investigación Fuden.\nClaudia González López. Departamento investigación Fuden.\nAmelia Amezcua Sánchez. Directora Ejecutiva Fuden.\nEquipo de comunicación:\nAna Eznarriaga. Community Manager. Periodista Fuden.\nGabriel Bernal Carbajal. Realizador Audiovisual. Fuden.",
#         "moreEntities": "",
#         "results_summary": "El impacto del video de sensibilización, en dos días, ha alcanzado las 5 mil visualizaciones. Esperamos un aumento exponencial con el tiempo.",
#         "results_link": "",
#         "impact": "científico, social, educativo, político",
#         "impact_examples": "",
#         "motivation": "Queremos realizar Investigación e Innovación responsable, teniendo en cuenta a los propios sujetos de estudio."
#     },
#     {
#         "id": "post-12977",
#         "name": "RedEXOS – Red de detección e intervención de especies exóticas invasoras de Canarias",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "RedEXOS es una Red de Alerta Temprana de especies exóticas con potencial para invadir cualquier espacio del archipiélago canario. Su objetivo es evitar el establecimiento de Especies Exóticas Invasoras (EEI) recogidas en el Catálogo Español de EEI, de especies con potencial invasor en Canarias que puedan ser identificadas como tales por la Comunidad Autónoma de Canarias, o de EEI recogidas en la Lista de especies exóticas invasoras preocupantes para la región ultraperiférica de las islas Canarias, así como sobre nuevos focos de aparición en puntos donde anteriormente no se encontraban presentes.",
#         "subtitle": "Red de Alerta Temprana para la detección e intervención de especies exóticas invasoras de Canarias",
#         "description": "El archipiélago canario es un conjunto de islas oceánicas caracterizadas por contar con una biodiversidad elevada. Según el Banco de datos de Biodiversidad de Canarias, BIOTA, las Islas Canarias superan las 24.400 especies y presenta un elevado número de endemismos, 680 plantas y más de 3.000 animales. El 1,5% del territorio español alberga más de la mitad de los endemismos vegetales del país. El patrimonio biológico canario es único gracias al clima y al aislamiento que han dado lugar a una elevada especiación. El problema es que la falta de adaptación a depredadores, la baja diversidad genética y una elevada vulnerabilidad frente a patógenos exóticos aumentan las probabilidades de pérdida de especies, sobre todo, en un contexto de globalización y cambio climático como el que tenemos actualmente.\nJunto a la destrucción de hábitats, las invasiones biológicas son una causa de pérdida de biodiversidad con especial incidencia en islas. El continuo movimiento de bienes y personas facilita la dispersión, deliberada o accidental, de especies de flora y fauna. En determinadas ocasiones, estas especies logran establecer poblaciones reproductoras autosuficientes y pasan a ser invasoras, lo que tiene un efecto negativo sobre la biodiversidad, la salud y la economía.\nRedEXOS es la Red de Alerta Temprana de Canarias para la detección e intervención de especies exóticas invasoras (Decreto 117/2020, de 19 de noviembre de 2020). El funcionamiento de la Red se sustenta en la información y actuaciones que, en el ámbito de sus competencias, realicen las Administraciones e instituciones colaboradoras de la Red de Alerta, así como la colaboración efectiva de la ciudadanía a través de diferentes canales. A través del número 646 601 457 de atención ciudadana la Red recoge información sobre avistamientos de invasoras. Además, una plataforma formada por un portal web y una aplicación libre para dispositivos móviles (RedEXOS), permiten que la ciudadanía, además de encontrar información sobre EEI en Canarias, interactúe con la Red de Alerta informando y geolocalizando avistamientos que posteriormente serán revisados por validadores. Una vez validado el avistamiento, el equipo de intervención se pondrá en marcha. El usuario recibirá la información sobre las actuaciones llevadas a cabo sobre su reporte.",
#         "keywords": "Animales, Biodiversidad, Biología, Ecología y Medioambiente, Educación, Gestión de Recursos Naturales, Insectos y Polinizadores, Naturaleza y Aire Libre, Océanos, Agua, Marino y Terrestre, Pájaros, Seguimiento de Especies a largo plazo",
#         "start_date": "1 de noviembre de 2017",
#         "end_date": "1 de noviembre de 2050",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/redexos-red-de-deteccion-e-intervencion-de-especies-exoticas-invasoras-de-canarias/",
#         "mainOrganisation": "Red De Detección E Intervención De Especies Exóticas Invasoras De Canarias / Gobierno En Canarias",
#         "responsibleEntity": "Consejería de Transición Ecológica, Lucha Contra el Cambio Climático y Planificación Territorial del Gobierno de Canarias",
#         "province": "Comunidad Autónoma de Canarias",
#         "howToParticipate": "Registrándose en la web RedEXOS o descargando la app RedEXOS (disponible para Android e iOS) y registrándose para comenzar a informar sobre las EEI que se encuentren en sus paseos por la naturaleza canaria.",
#         "equipment": "Simplemente un ordenador o un smartphone",
#         "public": "Todo tipo de público",
#         "participants": "10.000 a 100.000 personas",
#         "fundingTeam": "Personal técnico de la Dirección General de Lucha contra el Cambio Climático y Medio Ambiente del Gobierno de Canarias\nPersonal técnico de Gesplan, empresa pública del Gobierno de Canarias para la Gestión y Planeamiento Territorial y Medio Ambiente, S.A. (GESPLAN).",
#         "moreEntities": "Proyecto cofinanciado a través del Fondo Europeo de Desarrollo Regional (FEDER).",
#         "results_summary": "El proyecto, que comenzó como experiencia piloto del Gobierno de Canarias, adquirió el pasado mes de noviembre de 2020 el rango de Red de Alerta Temprana del Gobierno de Canarias. Su objetivo es el de evitar el establecimiento de nuevas EEI o nuevos focos de las ya existentes en el territorio insular.\nLa política de datos en abierto requerida por el Gobierno de Canarias en este proyecto colaborativo, permitirá el acceso público a la información disponible y actuaciones. El uso de la información está garantizado para que particulares, universidades y centros de investigación puedan usar los datos en las investigaciones que estén llevando a cabo. El potencial de la base de datos creada irá aumentando en la medida del aumento de usuarios activos.",
#         "results_link": "Página de acceso a avistamientos reportados a través de la app con datos descargable\nhttps://www3.gobiernodecanarias.org/cptss/sostenibilidad/biodiversidad/redexos/app/map",
#         "impact": "económico, educativo, medioambiental, político",
#         "impact_examples": "https://www.europapress.es/islas-canarias/noticia-canarias-elimina-casi-100-ejemplares-plumero-pampa-especie-invasora-2020-20210310141916.html\nhttps://www.canarias7.es/canarias/gran-canaria/el-camaleon-de-yemen-un-riesgo-para-invertebrados-endemicos-AY9177637?ref=https%3A%2F%2Fwww.google.com%2F",
#         "motivation": "La Ciencia Ciudadana ocupa un papel principal en los cambios que se están produciendo en las interacciones entre ciencia-sociedad-política gracias a la revolución digital."
#     },
#     {
#         "id": "post-12913",
#         "name": "COMPASS",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "(1) Evaluar la usabilidad una aplicación móvil que integra datos de salud individual, genera recomendaciones preventivas personalizadas y suministra de información sobre el Mapa de Activos de Salud del Ayuntamiento de Barcelona y (2) Evaluar la eficacia de dicha aplicación sobre el control de los factores de riesgo cardiovascular: reducción del consumo de tabaco y el peso, desarrollo regular de actividad física y de una dieta saludable; y cambios en la glicemia, presión arterial, colesterol y en la calidad de vida relacionada con la salud",
#         "subtitle": "Proyecto de ciencia ciudadana para evaluar la eficacia de una aplicación móvil en el control de los factores de riesgo cardiovascular",
#         "description": "El proyecto consta de dos objetivos. En el primero de ellos, se evaluó la usabilidad de la aplicación en un proyecto de ciencia ciudadana desarrollado con los estudiantes de 5º de primaria del colegio de educación infantil y primaria La Maquinista de Barcelona. COMPASS actuó como hilo conductor entre los diferentes contenidos a desarrollar durante el curso. De esta forma, nuestro proyecto de ciencia ciudadana se utilizó para formar al alumnado en metodología científica, se trabajaron los estilos de vida saludables y su importancia para la prevención de las enfermedades. Los niños y niñas también aprendieron el funcionamiento correcto de algunos instrumentos de medida sencillos, pero muy útiles a la hora de hacer prevención, como son el tensiómetro, la báscula o el tallímetro, y se entrenaron para su uso. Posteriormente, fueron ellos y ellas quienes pesaron, tallaron, midieron la tensión arterial y registraron el tipo de dieta y la actividad física de sus familiares, todo ello necesario para crear recomendaciones preventivas personalizadas. El proyecto se completó con las entrevistas realizadas por parte del equipo investigador a los participantes con el fin de conocer su opinión sobre la aplicación móvil y las recomendaciones personalizadas. A partir de las mismas, se diseñó una nueva versión de la aplicación cuya eficacia se evalúa en la segunda parte del proyecto. Los resultados de este primer objetivo se han publicado en la revista Informatics in Health and Social Care.\nEl segundo objetivo del proyecto, ahora mismo en marcha, se desarrollará con metodología de ciencia ciudadana en colaboración con los profesionales de Ateneu l'Harmonia, también de Barcelona. Se desarrollará un ensayo controlado aleatorizado en el cual se reclutará a unos 500 participantes que se seguirán durante 16 meses. Únicamente, el 50% de los participantes tendrán acceso a la aplicación, grupo de intervención, mientras que el otro 50% no tendrá acceso, grupo de control. El comité ejecutivo del proyecto, encargado del diseño y seguimiento del mismo, está formado por los profesionales del Ateneu y los investigadores del estudio.",
#         "keywords": "Medicina y Salud",
#         "start_date": "1 de enero de 2018",
#         "end_date": "30 de junio de 2022",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/compass/",
#         "mainOrganisation": "COMPASS",
#         "responsibleEntity": "Universitat de Barcelona",
#         "province": "Barcelona",
#         "howToParticipate": "Objetivo 1. Las y los científicos ciudadanos fueron las niñas y niños de 5º de primaria de la Escola La Maquinista. Durante el transcurso del proyecto aprendieron el funcionamiento correcto de algunos instrumentos de medida sencillos, pero muy útiles a la hora de hacer prevención, como son el tensiómetro, la báscula o el tallímetro, y se entrenaron para su uso. Posteriormente, fueron ellos y ellas quienes pesaron, tallaron, midieron la tensión arterial y registraron el tipo de dieta y la actividad física de sus familiares, todo ello necesario para crear recomendaciones preventivas personalizadas.\nObjetivo 2. Los profesionales del Ateneu Harmonia son las y los científicos ciudadanos. Formarán parte del comité ejecutivo del proyecto con las funciones de diseño, seguimiento y difusión del proyecto.",
#         "equipment": "Es necesario tener un smartphone con la aplicación COMPASS instalada",
#         "public": "Adultos (entre 18 y 65 años)",
#         "participants": "100 a 1.000 personas",
#         "fundingTeam": "María Grau Magaña: Médico Especialista Medicina Preventiva y Salud Pública y Doctora en Salud Pública. Investigadora Principal\nJorge L. Díaz: Médico Interno Residente Medicina Preventiva y Salud Pública. Investigador\nMontse Zayas. Licenciada en Farmacia. Investigadora\nMaria del Mar Vila: Investigadora pre-doctoral\nSusanna Tello: Técnico de logística y manejo de datos",
#         "moreEntities": "Consorcio de Investigación Biomédica en Red Epidemiología y Salud Pública (CIBERESP) Grupo 30\nIMIM - Institut Hospital del Mar d'Investigacions Mèdiques",
#         "results_summary": "Tras la ejecución del primer objetivo, pudimos crear una segunda versión de la app la cual presentaba una usabilidad significativamente mayor que la primera versión. Estos resultados pueden consultarse en la publicación: Díaz JL, Codern-Bové N, Zomeño MD, Lassale C, Schröder H, Grau M. Quantitative and qualitative evaluation of the COMPASS mobile app: a citizen science project. Inform Health Soc Care. 2021 Apr 13:1-13. doi: 10.1080/17538157.2021.1902332. Epub ahead of print. PMID: 33847218.\nRespecto al segundo objetivo, se espera que el empoderamiento individual, a través de recomendaciones personalizadas de realización de una dieta de estilo mediterráneo y la práctica de actividad física; junto con el empoderamiento comunitario, a través de la propuesta personalizada de activos para la salud promovidos por el Ateneu Harmonia, sirva para conseguir un mejor control de los factores de riesgo cardiovascular: reducción del consumo de tabaco y el peso, desarrollo regular de actividad física y de una dieta saludable; y cambios en la glicemia, presión arterial, colesterol y en la calidad de vida relacionada con la salud.",
#         "results_link": "Página web del equipo de investigación: www.ub.edu/compass\nPágina web de la revista donde se han publicado los resultados: https://www.tandfonline.com/doi/abs/10.1080/17538157.2021.1902332?journalCode=imif20",
#         "impact": "científico, social, educativo, tecnológico",
#         "impact_examples": "Investigación responsable: poniendo el foco en el paciente. Revista El·lipse: https://ellipse.prbb.org/es/investigacion-responsable-poniendo-el-foco-en-el-paciente/\nValidación de un método de autocribado del riesgo cardiovascular. Zinkinn [página web]: https://www.zinkinn.es/validacion-de-un-metodo-de-autocribado-del-riesgo-cardiovascular\nLa ciencia ciudadana llega a la escuela de primaria. Heraldo Tercer Milenio: https://www.heraldo.es/noticias/sociedad/2019/10/24/la-ciencia-ciudadana-llega-a-la-escuela-de-primaria-con-el-proyecto-compass-1340136.html?autoref=true\nCOMPASS: Experiencias y lecciones aprendidas. I Reunión Virtual Sociedad Española de Epidemiología: https://twitter.com/seepidemiologia/status/1321823690837925890",
#         "motivation": "Es posible y necesario implementar proyectos de Ciencia Ciudadana en salud"
#     },
#     {
#         "id": "post-12766",
#         "name": "Arqueología satelital",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "Poner en valor y dar a conocer a la sociedad yacimientos y localizaciones arqueológicas, históricas o etnográficas mediante el uso de las nuevas tecnologías. Todos los ciudadanos pueden aportar sus conocimientos y compartirlos con el resto creando recursos educativos y culturales geolocalizados.",
#         "subtitle": "Programa de ciencia ciudadana para localizar y poner en valor yacimientos arqueológicos/históricos/etnográficos mediante datos e imágenes por teledetección satelital y GPS.",
#         "description": "Usando datos de satélites, mapas, documentos varios en donde se referencie localizaciones de especial interés cultural, etnográfico o arqueológico para poder sr compartidas desde una plataforma digital y darle valor añadido mediante la creación de recursos culturales y educativos relacionados.",
#         "keywords": "Biodiversidad, Clima y Meteorología, Cultura y Arqueología, Educación, Espacio y Astronomía, Geología y Ciencias de la Tierra, Gestión de Recursos Naturales, Informática y Ciencias de la Computación",
#         "start_date": "1 de abril de 2017",
#         "end_date": "3 de abril de 2050",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/arqueologia-satelital/",
#         "mainOrganisation": "Edicca - Asoc. Educadores, Divulgadores Y Comunicadores Para La Ciencia Y Las Artes Del Principado De Asturias",
#         "responsibleEntity": "EDICCA",
#         "province": "Principado de Asturias",
#         "howToParticipate": "Ayudando con datos actualizados para ser incorporados al proyecto. Creando contenidos y recursos educativos/culturales.",
#         "equipment": "Ordenador con internet\nCámara de fotos\nEquipo para trabajo de campo\nGPS\nSmartphone o tablet",
#         "public": "Todo tipo de público",
#         "participants": "100 a 1.000 personas",
#         "fundingTeam": "Juan Marcos Alvarez Merinero\nAlberto Alvarez Peña\nMónica Franco González",
#         "moreEntities": "",
#         "results_summary": "Primeras actuaciones sobre un yacimiento aún sin analizar con muy buena aceptación en medios. Asociaciones de vecinos muy interesadas. Creamos una visita guiada de manera virtual para evitar dañar el entorno, pero pudiéndolo visitar para mejorar su comprensión.",
#         "results_link": "",
#         "impact": "científico, económico, social, educativo, medioambiental, político, tecnológico",
#         "impact_examples": "https://www.lne.es/aviles/2017/10/30/castro-podes-movil-19177084.html\nhttps://www.rtpa.es/noticias-ciencia:Un-paseo-por-el-castro-de-la-Punta-del-Castiello,-en-Samartin-de-Podes_111510484469.html",
#         "motivation": "La cultura no es lo que se hace en el tiempo libre, es lo que nos hace libres todo el tiempo."
#     },
#     {
#         "id": "post-12715",
#         "name": "CoastSnap Cádiz",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "Crear una base de datos con imágenes compartidas de la playa, con el fin de involucrar a la ciudadanía en el seguimiento de los cambios que experimenta la playa",
#         "subtitle": "Ciencia ciudadana para el seguimiento de playas",
#         "description": "Para comprender el impacto que producen en las playas las condiciones cambiantes de oleaje y mareas, es necesario monitorizar cómo cambia la costa a lo largo del tiempo. La ciencia ciudadana ha abierto una vía en la cual son los propios ciudadanos los que, con su colaboración, pueden ayudar en estos seguimientos a medio y largo plazo. El proyecto CoastSnap Cádiz es parte de una iniciativa internacional, y consiste en la instalación de un soporte de altura y coordenadas conocidas, donde los usuarios pueden colocar su dispositivo smartphone y tomar una foto de la costa. Una vez tomada la foto, la comparten por e-mail o a través de las redes sociales. Las fotos tomadas por la comunidad se utilizan para medir con precisión los cambios en la playa y establecer un registro a largo plazo de la posición de la costa, permitiendo estudiar la dinámica de dicha playa. Los resultados obtenidos a partir de las imágenes se publican periódicamente en las mismas redes sociales, ayudando a la ciudadanía a comprender la utilidad de los datos, los procesos dinámicos que se dan en la costa y la importancia de la adecuada conservación de la playa. En este caso, la playa elegida es la de Santa María del Mar, playa urbana de la ciudad de Cádiz.",
#         "keywords": "Clima y Meteorología, Ecología y Medioambiente, Geografía, Geología y Ciencias de la Tierra, Gestión de Recursos Naturales, Océanos, Agua, Marino y Terrestre",
#         "start_date": "19 de octubre de 2020",
#         "end_date": "1 de marzo de 2050",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/coastsnap-cadiz/",
#         "mainOrganisation": "CoastSnap Cádiz",
#         "responsibleEntity": "Grupo de Geomorfología Litoral de la Universidad de Cádiz",
#         "province": "Cádiz",
#         "howToParticipate": "La ciudadanía puede participar mediante el uso del soporte para smartphones situado junto a la playa. Sólo hay que colocar el teléfono móvil en el soporte, hacer una foto (sin filtros ni zoom) y compartirla a través del correo electrónico que aparece en el cartel junto al soporte, o bien en las redes sociales con la etiqueta #CoastSnapCadiz. Las imágenes proporcionarán información muy valiosa sobre los cambios que se producen en la playa. Los ciudadanos podrán ver los resultados del análisis de sus imágenes en las redes sociales del proyecto, comprobando la utilidad de los datos que ellos mismos han proporcionado.",
#         "equipment": "Smartphone",
#         "public": "Todo tipo de público",
#         "participants": "1.000 a 10.000 personas",
#         "fundingTeam": "Laura del Río Rodríguez, Profesora Titular del Dpto. Ciencias de la Tierra de la Universidad de Cádiz, coordinadora del proyecto\nTheocharis Plomaritis, Profesor Ayudante Doctor del Dpto. Física Aplicada de la Universidad de Cádiz, investigador\nJavier Benavente González, Profesor Titular del Dpto. Ciencias de la Tierra de la Universidad de Cádiz, investigador\nEsther Simancas González, Profesora Ayudante Doctor del Dpto. Marketing y Comunicación de la Universidad de Cádiz, investigadora\nEsther García González, Profesora Ayudante Doctor del Dpto. Didáctica de la Universidad de Cádiz, investigadora",
#         "moreEntities": "Ayuntamiento de Cádiz, Vicerrectorado de Política Científica de la Universidad de Cádiz",
#         "results_summary": "Los investigadores utilizarán las fotos tomadas por los ciudadanos para medir los cambios de la playa, que es un ambiente muy dinámico. Los resultados mostrarán cómo responde la playa a las condiciones variables del océano, por lo que se podrán detectar diferentes procesos: pérdidas de arena (erosión), por ejemplo debidas a la acción de temporales, recuperación de arena, cambios a medio plazo, etc. El conocimiento de estos procesos ayudará a comprender mejor cómo funciona la playa y por lo tanto a gestionarla de la mejor manera posible.",
#         "results_link": "https://www.facebook.com/Coast-Snap-C%C3%A1diz-100264748577405",
#         "impact": "científico, educativo, medioambiental",
#         "impact_examples": "",
#         "motivation": "Si la ciudadanía se siente parte de algo, lo comprende mejor y lo aprecia más."
#     },
#     {
#         "id": "post-12667",
#         "name": "Observatorio Ciudadano de la Sequía",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "El Observatorio Ciudadano de la Sequía es un portal de ciencia ciudadana para avanzar en el mejor conocimiento del riesgo de sequía en España. Para ello, propone una nueva metodología que favorece el trabajo deliberativo y colaborativo, facilita una participación pública activa y real y mejora los procesos de toma de decisiones en materia de gestión del agua y de la sequía y, en definitiva, el necesario diálogo entre la ciencia, la política y la sociedad.",
#         "subtitle": "Proyecto de ciencia ciudadana para avanzar en el mejor conocimiento del riesgo de sequía en España",
#         "description": "El Observatorio Ciudadano de la Sequía facilita el acceso a información sobre gestión y planificación del agua y de las sequías, y se construye como un lugar de encuentro de distintas disciplinas y saberes, que pretende facilitar el fortalecimiento social e institucional mediante la coproducción del conocimiento. Gracias a la comunidad articulada en torno al Observatorio se podrán calcular indicadores de vulnerabilidad al riesgo de sequía —que se han demostrado claves para su completa comprensión— y se evaluarán distintas alternativas de gestión del agua y de la sequía. Con ello no solo se genera nuevo conocimiento sino también opiniones informadas que mejorarán la calidad del debate público sobre la materia. Para facilitar y fortalecer la participación de ciudadanos, responsables de gestión, colectivos profesionales y comunidad científica, se han desarrollado nuevas herramientas basadas en tecnologías de información geográfica, aplicaciones web e inteligencia artificial.",
#         "keywords": "Ciencias Sociales, Clima y Meteorología, Ecología y Medioambiente, Geografía, Gestión de Recursos Naturales, Informática y Ciencias de la Computación, Océanos, Agua, Marino y Terrestre",
#         "start_date": "1 de noviembre de 2020",
#         "end_date": "22 de marzo de 2050",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/observatorio-ciudadano-de-la-sequia/",
#         "mainOrganisation": "Observatorio Ciudadano De La Sequía",
#         "responsibleEntity": "Universidad Pablo de Olavide (UPO), en colaboración con la FECYT",
#         "province": "Sevilla",
#         "howToParticipate": "El objetivo fundamental de la participación de los científicos ciudadanos es la construcción de tres indicadores de percepción y de opinión pública que alimentan el cálculo de un Índice de Vulnerabilidad a la Sequía. En particular, los participantes asumen un rol central y decisivo en la construcción de indicadores que permiten valorar la capacidad de adaptación de poblaciones y territorios a episodios de sequía en un contexto de cambio climático.\nAdemás, los científicos ciudadanos participarán con el Observatorio compartiendo información de interés sobre el estado del agua y la sequía en sus territorios a través de formularios web y redes sociales, deliberando sobre medidas de gestión en distintos talleres y diseñando Story Maps y cartografías colaborativas para difundir experiencias y conocimientos locales. El Observatorio ensayará también una nueva interacción con los usuarios a través de un ChatBot conversacional.",
#         "equipment": "Ordenador o smartphone.",
#         "public": "Todo tipo de público",
#         "participants": "1.000 a 10.000 personas",
#         "fundingTeam": "Pilar Paneque Salgado (responsable): Catedrática de Geografía Humana (UPO)\nJesús Vargas Molina: Investigador Postdoctoral de Geografía Humana (UPO)\nAlicia Troncoso Lora: Catedrática de Lenguajes y Sistemas Informáticos (UPO)\nJosé Fco. Torres Maldonado: Investigador del Data Science & Big Data Research Lab (UPO)\nVirginia Rodríguez Díaz: Profesora de Geografía Humana y técnico SIG (UPO)\nRegina Lafuente Fernández: Técnico Superior de Investigación, Sociología (IESA-CSIC)\nErnesto Ganuza Fernández: Científico titular, Sociología (IPP-CSIC)\nAnabel Sánchez Plaza: Técnico Superior de Investigación, Cambio Global (CREAF)\nAnnelies Broekman: Técnico Superior de Investigación, Gobernanza del Agua (CREAF)\nJosé Luis del Río Anguita: Técnico Superior de Investigación, Agricultura (IFAPA)\nYago Martín González: Investigador Postdoctoral, Geografía Humana y TIG (UCF, USA)\nJaime Paneque Gálvez: Profesor de Geografía Ambiental (CIGA-UNAM, México)\nRuth Pérez Lázaro: Técnico Superior de Investigación, Ciencia Ciudadana (UPO)",
# ...
#         "motivation": ""
#     },
#     {
#         "id": "post-9361",
#         "name": "MARduino",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "El proyecto “MARduino: mi boya, nuestros datos y el mar” pretende sensibilizar a la ciudadanía sobre la importancia de la preservación de la calidad del agua del mar enseyando a construir boyas oceanográficas de bajo coste que miden la transparencia del agua del mar: un indicador básico que ayuda a los investigadores a entender y predecir cambios en la calidad del agua del mar.",
#         "subtitle": "\"MARduino: mi boya, nuestros datos y el mar\"",
#         "description": "A través de este proyecto los ciudadanos pueden aprender a construir una boya oceanográfica KdUINO que tiene unos sensores que captan la intensidad de la luz del sol a diferentes profundidades dentro del agua y que se puede colocar en el mar (en un puerto o en un espigón) durante meses. Estos sensores acumulan la información sobre la cantidad de luz del sol que les llega. Los datos se pueden descargar posteriormente a nuestros móviles mediante una aplicación diseñada específicamente.\nMARduino no es un proyecto aislado, es una de las muchas actividades y acciones que desde el proyecto científico europeo Citclops, una gran plataforma formada por diferentes expertos .",
#         "keywords": "Biodiversidad, Ecología y Medioambiente, Océanos, Agua, Marino y Terrestre",
#         "start_date": "1 de enero de 2013",
#         "end_date": "1 de enero de 2020",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/marduino/",
#         "mainOrganisation": "MARduino",
#         "responsibleEntity": "Jaume Piera, Raul Bardají, Carine Simón",
#         "province": "Barcelona",
#         "howToParticipate": "Participando de forma consciente e informada en un experimento para ser estudiados (tipo pruebas piloto…)\nAyudando a recolectar datos para uso científico (tipo toma de muestras geolocalizadas, rellenando encuestas…)\nColaborando en plataformas donde se comparten/evalúan/evolucionan ideas para resolver colectivamente problemas (tipo repositorios de códigos o de problemas…)",
#         "equipment": "ordenador, smarthphone",
#         "public": "Todo tipo de público",
#         "participants": "",
#         "fundingTeam": "",
#         "moreEntities": "1000001Labs, CEAB-CSIC, CREAF",
#         "results_summary": "",
#         "results_link": "",
#         "impact": "científico, social, educativo, medioambiental, tecnológico",
#         "impact_examples": "10.1109/OCEANS-TAIPEI.2014.6964550",
#         "motivation": ""
#     },
#     {
#         "id": "post-12201",
#         "name": "ÓSCAR DÍAZ",
#         "type": "persona de ciencia ciudadana",
#         "aim": "Colaboré en un proyecto para evaluar la felicidad personal a partir de los datos aportados por la ciudadanía.",
#         "subtitle": "",
#         "description": "",
#         "keywords": "",
#         "start_date": "",
#         "end_date": "",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/oscar-diaz/",
#         "mainOrganisation": "ÓSCAR DÍAZ",
#         "responsibleEntity": "USJ",
#         "province": "Zaragoza",
#         "howToParticipate": "",
#         "equipment": "",
#         "public": "Todo tipo de público",
#         "participants": "",
#         "fundingTeam": "",
#         "moreEntities": "Fundación Ibercivis",
#         "results_summary": "http://www.aragondigital.es/noticia.asp?notid=116879\nhttp://www.heraldo.es/noticias/aragon/2014/01/22/el_examen_felicidad_266591_300.html",
#         "results_link": "http://www.ibercivis.es/la-nueva-aplicacion-happy-up-es-presentada-publicamente-en-zaragoza/",
#         "impact": "social",
#         "impact_examples": "",
#         "motivation": ""
#     },
#     {
#         "id": "post-12207",
#         "name": "Socientize",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "Proyecto financiado por la Comisión Europea que ha sido destacado como proyecto bandera en la Agenda Digital para Europa y referenciado por las distintas comunidades. Experimentos, coordinación, soporte, repositorio de contenidos, política, conferencias. Actualmente Ibercivis apoya este proyecto.",
#         "subtitle": "Society as infrastructure for e-science via technology, innovation and creativity",
#         "description": "Socientize fue el primer proyecto financiado por el 7PM que abordó en profundidad la ciencia ciudadana. Como se define en el Libro Blanco sobre la ciencia ciudadana en Europa, escrito por más de 100 participantes en este proyecto, la ciencia ciudadana se refiere a la participación del público en general en actividades de investigación científica cuando contribuyen activamente a la ciencia, ya sea con su esfuerzo intelectual o el conocimiento circundante o con su herramientas y recursos. El proyecto buscó un enfoque holístico al mapear las actividades existentes en ciencia ciudadana, pero también creando otras nuevas. Todo esto, una vez analizado, sirvió de base para la creación de los Libros Verdes y Blancos sobre Ciencia Ciudadana en Europa, que fue una de las bases del programa SWAFS en H2020.\nEn particular, el proyecto logró:\n-Fomentar la interacción y coordinación entre todos los actores de la ciencia ciudadana: investigadores, proveedores de recursos, administradores de sistemas y voluntarios de la sociedad. Se creó una interfaz común ofreciendo herramientas y espacios de trabajo comunes para todos ellos, mediante la implementación de la investigación de atracción de la sociedad y la presentación de resultados de una manera atractiva.\n-Promoción de las capacidades de las infraestructuras humanas. El objetivo era convencer a otros proveedores y usuarios de infraestructura de investigación, investigadores especializados y personas en casa de que es posible hacer ciencia de alto nivel abriendo los laboratorios y facilitando la interacción y la contribución de los científicos aficionados.\n-Integración de soluciones existentes y comunidades de usuarios que tienen como objetivo compartir experiencias e innovar creando soluciones comunes. Este proyecto también implementó un conjunto de experimentos concretos que se enfocan en temas específicos y agregó nuevos recursos a las infraestructuras de investigación disponibles.\n-Recopilación e intercambio de mejores prácticas de usuario orientadas a la investigación, usuarios y proveedores de infraestructuras, así como recomendaciones de los responsables de políticas para implementar la ciencia ciudadana.",
#         "keywords": "Ciencias Sociales",
#         "start_date": "1 de octubre de 2012",
#         "end_date": "31 de diciembre de 2014",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/socientize/",
#         "mainOrganisation": "Socientize",
#         "responsibleEntity": "Bifi de la Universidad de Zaragoza",
#         "province": "Zaragoza",
#         "howToParticipate": "Realizando experimentos de ciencia ciudadana",
#         "equipment": "Ordenador, smartphone, cámara de fotos....",
#         "public": "Todo tipo de público",
#         "participants": "1.000 a 10.000 personas",
#         "fundingTeam": "Alfonso Tarancón, Beatriz Antonli, Fermín Serrano, Francisco Sanz, Carlos Val, Eduardo Lostal, Mari Carmen Ibáñez, Manuel Pérez Alconchel, Teresa Holocher-Ertl, Barbara Kieslinger, Claudia Fabian, Cândida G. Silva, Rui M. M. Brito, Francisco Brasileiro",
#         "moreEntities": "UZ, Tecnara, UC, UFCG, ZSI, UB, CERN, EU-BON, ECSA, Ibercivis",
#         "results_summary": "https://www.researchgate.net/publication/271130828_SOCIENTIZE_participatory_experiments_dissemination_and_networking_activities_in_perspective\nhttps://ec.europa.eu/digital-single-market/en/citizen-science\nhttps://ec.europa.eu/digital-single-market/news/excellent-science-digital-age\nhttps://twitter.com/erc_research/status/649247496212979713\nhttps://ec.europa.eu/futurium/en/digital4science/tags/citizen-science",
#         "results_link": "Fermín Serrano Sanz, Teresa Holocher-Ertl, Barbara Kieslinger, Francisco Sanz García, Cândida G. Silva, White Paper on Citizen Science for Europe, In Socientize Consortium 2014. University of Zaragoza, Zentrum für Soziale Innovation, Tecnara, Universidade Federal Campina Grande, Universidade de Coimbra, Museu da Ciência da Universidade de Coimbra (Eds.), September 22, 2014.\nhttps://ec.europa.eu/digital-single-market/en/news/project-socientize-announces-white-paper-citizen-science-their-final-conference",
#         "impact": "científico, social, educativo, político, tecnológico",
#         "impact_examples": "https://ibercivis.es/en-socientize-taking-citizen-science-senior-universities/\nhttps://ibercivis.es/la-aplicacion-cell-spotting-del-proyecto-socientize-premiada-en-portugal/\nhttps://ibercivis.es/proyecto-socientize-destacado-por-la-comision-europea/\nhttps://ibercivis.es/entrevista-a-fermin-serrano-acerca-del-proyecto-europeo-socientize/",
#         "motivation": ""
#     },
#     {
#         "id": "post-9327",
#         "name": "Aficca",
#         "type": "proyecto de ciencia ciudadana",
#         "aim": "La Asociación para el Fomento de la Investigación Científica en Casa (Aficca) nace con el objetivo de dar a conocer el mundo de la Computación Distribuida a todos los ciudadanos, empresas e instituciones. Fundado por miembros de los distintos equipos que conforman la Plataforma CANALBoinc, Aficca organizará y participará en conferencias, charlas, jornadas y demostraciones con el fin de divulgar la colaboración con la ciencia por parte de toda la sociedad, demostrando que tener La Ciencia en Casa, es posible. Asimismo, prestará asesoramiento técnico a todas las empresas, instituciones y usuarios que deseen incorporarse a la computación distribuida.",
#         "subtitle": "",
#         "description": "",
#         "keywords": "Informática y Ciencias de la Computación",
#         "start_date": "11 de noviembre de 2011",
#         "end_date": "11 de noviembre de 2031",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/aficca/",
#         "mainOrganisation": "Aficca",
#         "responsibleEntity": "Fundado por miembros de los distintos equipos que conforman la Plataforma CANALBoinc",
#         "province": "Córdoba",
#         "howToParticipate": "Poniendo su ordenador a trabajar con el programa BOINC, es decir, la ciudadanía cede capacidad de cálculo mientras su ordenador está conectado a internet pero sin ser usado por el usario",
#         "equipment": "Ordenador",
#         "public": "Todo tipo de público",
#         "participants": "10.000 a 100.000 personas",
#         "fundingTeam": "",
#         "moreEntities": "bercivis, CANALBoinc, IBM, Universidad de Córdoba",
#         "results_summary": "",
#         "results_link": "",
#         "impact": "social, educativo, tecnológico",
#         "impact_examples": "http://www.canalboinc.com/modules/newbb/",
#         "motivation": ""
#     },
#     {
#         "id": "post-9305",
#         "name": "Fundación Ibercivis",
#         "type": "institución de ciencia ciudadana",
#         "aim": "La Fundación Ibercivis es una fundación privada sin ánimo de lucro con el objetivo de promover la ciencia ciudadana tanto a nivel regional como nacional e internacional.",
#         "subtitle": "",
#         "description": "Desarrollamos, promovemos, visibilizamos e investigamos Ciencia Ciudadana\n#HacemosCienciaCiudadana",
#         "keywords": "Animales, Biogeografía, Biología, Ciencia de los Alimentos, Ciencias de la Agricultura y Veterinaria, Ciencias Políticas, Ciencias Químicas, Ciencias Sociales, Clima y Meteorología, Cultura y Arqueología, Ecología y Medioambiente, Educación, Espacio y Astronomía, Física, Genética, Geografía, Geología y Ciencias de la Tierra, Gestión de Recursos Naturales, Informática y Ciencias de la Computación, Insectos y Polinizadores, Medicina y Salud, Naturaleza y Aire Libre, Océanos, Agua, Marino y Terrestre, Pájaros, Seguimiento de Especies a largo plazo, Sonido, Transporte",
#         "start_date": "1 de enero de 2011",
#         "end_date": "1 de agosto de 2050",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/fundacion-ibercivis/",
#         "mainOrganisation": "Ibercivis",
#         "responsibleEntity": "Fundación Ibercivis",
#         "province": "Zaragoza",
#         "howToParticipate": "Participando de forma consciente e informada en un experimento para ser estudiados (tipo pruebas piloto…)\nCreando o compartiendo recursos y herramientas para ciencia ciudadana (tipo computación voluntaria, crowdfunding…)\nAyudando a recolectar datos para uso científico (tipo toma de muestras geolocalizadas, rellenando encuestas…)\nAyudando a interpretar datos para uso científico (tipo análisis de imágenes científicas…)\nParticipando en serious games (tipo gymkana, puzzles…)\nParticipando en actuaciones comunitarias que buscan evidencia o rigor científica para resolver problemas sociales (tipo actuaciones cuestionando gestión urbanística…)\nColaborando en plataformas donde se comparten/evalúan/evolucionan ideas para resolver colectivamente problemas (tipo repositorios de códigos o de problemas…)",
#         "equipment": "En algunos proyectos sí son necesarios los dispositivos que suelen usarse hoy en día como: ordenador, smartphone, cámara de fotos, utensilios",
#         "public": "Todo tipo de público",
#         "participants": "más de 100.000 personas",
#         "fundingTeam": "Jesús Clemente. Director de la Fundación\nFrancisco Sanz. Director Ejecutivo\nVictor Castelo Subdirector de la Fundación\nMaricarmen Ibañez. Responsable de administración y gestión de proyectos\nLaude Guardia. Administración y gestión de proyectos\nVictor Val. Desarrollo de software\nMaite Pelacho. Investigadora y gestora de proyectos\nDaniel Lisbona. Comunicación y gestión de proyectos\nRosa Arias. Comunicación y gestión de proyectos\nNora Salas. Investigadora y gestora de proyectos",
#         "moreEntities": "Ministerio de Ciencia e Innovación",
#         "results_summary": "Informes, papers, contribuciones a investigaciones científicas, aprendizaje de la ciudadanía",
#         "results_link": "https://ibercivis.es/blog/",
#         "impact": "científico, social, educativo, medioambiental, político, tecnológico",
#         "impact_examples": "https://ibercivis.es/blog/",
#         "motivation": ""
#     },
#     {
#         "id": "post-9357",
#         "name": "Zaragoza Activa",
#         "type": "institución de ciencia ciudadana",
#         "aim": "Somos un ecosistema público de personas, empresas y proyectos para fomentar el emprendimiento, la creatividad y la innovación ciudadana. La ciencia ciudadana es un vector tangencial a nuestra línea de trabajo",
#         "subtitle": "",
#         "description": "Visitas Guiadas\nRed ZAC\nVivero de Emprendedores : 17 oficinas para emprendedores\nSemillero de Ideas: una pre incubadora de empresas\nZona Empleo: dirigida a desempleados\nLa Colaboradora: un espacio de inteligencia colectiva\nYuzz: una lanzadera de proyectos para jóvenes menores de 30\nInfoActiva: una asesoría para emprendedores\nMade in Zaragoza: Cluster de economía creativa\nSerpiente Roja\nThinkZAC: una laboratorio de conocimiento nómada\nBJCubit: la primera biblioteca para jóvenes en España",
#         "keywords": "Educación",
#         "start_date": "1 de junio de 2010",
#         "end_date": "",
#         "url": "https://ciencia-ciudadana.es/proyecto-cc/zaragoza-activa/",
#         "mainOrganisation": "Zaragoza Activa",
#         "responsibleEntity": "Ayuntamiento de zaragoza",
#         "province": "Zaragoza",
#         "howToParticipate": "Participando de forma consciente e informada en un experimento para ser estudiados (tipo pruebas piloto…)\nParticipando en serious games (tipo gymkana, puzzles…)",
#         "equipment": "",
#         "public": "Todo tipo de público",
#         "participants": "10.000 a 100.000 personas",
#         "fundingTeam": "Raúl Oliván Cortés, Belén Gracia, Milagros Arrebola, Jesús Alaviano, José Ramón Insa, Javier Fernández, Jesús Alquezar",
#         "moreEntities": "",
#         "results_summary": "",
#         "results_link": "",
#         "impact": "social, educativo",
#         "impact_examples": "",
#         "motivation": ""
#     }
# ]

# %%
df_SP_projects=pd.DataFrame.from_dict(lista_diccionarios)

# %%
if (EXPORT_JSON):
    with open('SpanishInitiatives.json', 'w', encoding='utf-8') as fp:
        df_SP_projects.to_json(fp, force_ascii=False)

# %%
if (EXPORT_JSON):
    with open('SpanishPeople.json', 'w', encoding='utf-8') as fp:
        df_SP_projects[df_SP_projects["type"]=="persona de ciencia ciudadana"].to_json(fp, force_ascii=False)
        
    with open('SpanishInstitutions.json', 'w', encoding='utf-8') as fp:
        df_SP_projects[df_SP_projects["type"]=="institución de ciencia ciudadana"].to_json(fp, force_ascii=False)
    
    with open('SpanishProjects.json', 'w', encoding='utf-8') as fp:
        df_SP_projects[df_SP_projects["type"]=="proyecto de ciencia ciudadana"].to_json(fp, force_ascii=False)

# %% [markdown]
# ### EDUCATIONAL RESOURCES

# %%
if (SCRAP_SPANISH):

    #Set up the path to the chrome driver
    driver= webdriver.Chrome('./chromedriver.exe')
    driver.get('https://ciencia-ciudadana.es/category/recursos_educativos/')

    #Get all the educational resources names and links and store them in a list
    educational_resources = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')
    
    educational_resources_list=[]

    for er in educational_resources:
        title=er.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
        link = title.get_attribute('href')

        this_er={"Title": title.text, "Link": link}
        educational_resources_list.append(this_er)
        
    #Since there is more than one page with educational resources
    num_pages = driver.find_elements_by_xpath('//a[@class="wpv-archive-pagination-link js-wpv-archive-pagination-link page-link"]')
        
    links_pages=[]
    for page in num_pages:
        links_pages.append(page.get_attribute("href"))
        
    driver.close()

# %%
links_pages
# Out:
# ['http://ciencia-ciudadana.es/category/recursos_educativos/page/2/']

# %%
if (SCRAP_SPANISH):
    
    driver= webdriver.Chrome('./chromedriver.exe')
#Go to the next page with educational resources and do the same
    for i in range(len(links_pages)):
        driver.get(links_pages[i])
        #Get all the educational resources names and links and store them in a list
        educational_resources = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')

        for er in educational_resources:
            title=er.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
            link = title.get_attribute('href')

            this_er={"Title": title.text, "Link": link}
            educational_resources_list.append(this_er)
    #educational_resources_list
    driver.close()

# %%
if (SCRAP_SPANISH):

    driver= webdriver.Chrome('./chromedriver.exe')

    #Create a list of dictionaries
    lista_diccionarios_er=[]

    #Iterate, for every resource in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(educational_resources_list)):
        educational_resource_dict={}

        driver.get(educational_resources_list[i]["Link"])

        educational_resource_dict["name"]=educational_resources_list[i]["Title"]        
        educational_resource_dict["url"]=educational_resources_list[i]["Link"]

        content=driver.find_element_by_xpath("//div[@id='left-area']")

        text_list=[]
        sentences = content.find_elements_by_xpath("//p")
    
        for i in range(len(sentences)-4):
            if(sentences[i].text!=""):
                text_list.append(sentences[i].text)

        keywords=[]
        strong=driver.find_elements_by_xpath("//strong")
        for negrita in strong:
            keywords.append(negrita.text)
            
        educational_resource_dict["abstract"]=text_list
        educational_resource_dict["keywords"]=keywords
        
        lista_diccionarios_er.append(educational_resource_dict)
    driver.close()
    #lista_diccionarios_er
    jprint(lista_diccionarios_er)
# Out:
# [
#     {
#         "name": "CIENCIA CIUDADANA Y SALUD EN “VITAL OPEN SCIENCE”",
#         "url": "https://ciencia-ciudadana.es/vital_open_science_ciencia_ciudadana_y_salud/",
#         "abstract": [
#             "La Programación “Vital Open Science”, llevada a cabo gracias a la Fundación Vital junto con la Asociación sin ánimo de lucro Biook, consiste en una serie de webinars dirigidos a la comunidad educativa de Álava, si bien, una vez compartidos en el canal de YouTube de la Fundación Vital, constituyen un recurso abierto para toda la comunidad educativa. Los objetivos son: impulsar la cultura científica y la innovación social y promocionar la divulgación científica, técnica y deportiva. ",
#             "Ricardo Mutuberría, director de Biook, es biotecnólogo, divulgador científico e impulsor de los movimientos de ciencia comunitaria y ciudadana. El Objetivo de Biook es hacer posible que cualquier persona pueda introducirse en el mundo de la ciencia, como puede hacerlo en el de la música, el teatro, la cultura en general. Mireya Fernández, bióloga molecular, máster en neurociencia y en comunicación científica, es la coordinadora de comunicación científica de Biook y la moderadora de los webinars.",
#             "En particular, en el webinar titulado ‘Ciencia Ciudadana y Salud’ se presentan algunos de los proyectos desarrollados en España y que el Observatorio de la Ciencia Ciudadana En España visibiliza y promociona a través de sus eventos, redes sociales y de su plataforma web. Ricardo Mutuberría recomienda hacer una visita por la web del Observatorio – proyecto de Ibercivis con la colaboración de la Fundación Española para la Ciencia y la Tecnología (FECYT)- Ministerio de Ciencia e Innovación – y a continuación se presentan las siguientes iniciativas de ciencia ciudadana relacionadas con la salud: Biodiversidad Virtual, i-naturalist, Natusfera, Planttes, Mosquito Alert, Spot Warriors y el programa de ciencia ciudadana promovido por el Ayuntamiento de Vitoria-Gasteiz. Además, son entrevistados Santi Escartín, responsable del área de educación de Mosquito Alert, y Gorka Belamendia, responsable de los programas de ciencia ciudadana desde el Ayuntamiento de Vitoria-Gazteiz. Se introduce también el proyecto Somos científicos y científicas, sácanos de aquí. Finalmente, a partir del minuto 45, se entrevista a Maite Pelacho, coordinadora del Observatorio de la Ciencia Ciudadana en España, quien explica brevemente el concepto ‘ciencia ciudadana’ y sus relaciones con la salud, más en particular en el ámbito de la educación.",
#             "Todos los webinars, publicados en abierto en el canal de YouTube de la Fundación Vital, están disponibles aquí."
#         ],
#         "keywords": [
#             "“Vital Open Science”,",
#             "Fundación Vital",
#             "Biook",
#             "impulsar la cultura científica y la innovación social y promocionar la divulgación científica, técnica y deportiva. ",
#             "Ricardo Mutuberría,",
#             "Mireya Fernández",
#             "‘Ciencia Ciudadana y Salud’",
#             "Observatorio de la Ciencia Ciudadana En España",
#             "Santi Escartín",
#             "Gorka Belamendia",
#             "Maite Pelacho"
#         ]
#     },
#     {
#         "name": "GUÍA DIDÁCTICA DE PÁJAROS EN LA NUBE – DISEÑO Y FABRICACIÓN",
#         "url": "https://ciencia-ciudadana.es/guia-didactica-de-pajaros-en-la-nube-diseno-y-fabricacion/",
#         "abstract": [
#             "Pájaros en la Nube es un proyecto de ciencia ciudadana en el aula, que cuenta en su edición de 2020 con 85 centros de toda España que monitorizarán con estas casetas la fauna insectívora de su entorno, enviando sus datos a la nube a través del internet de las cosas.",
#             "Esta guía didáctica de fabricación, realizada junto a la ESDA – Escuela Superior de Diseño de Aragón, es un documento con el que que trabajar en el aula en la introducción al proceso de diseño y prototipado industrial.",
#             "A través de este documento podéis conocer el proceso de diseño de la caseta y proponer actividades en el aula relacionadas con el prototipado y diseño industrial.",
#             "La guía está publicada bajo licencia creative commons 4.0 y puede ser descargada, utilizada y/o modificada siempre y cuando se haga referencia a sus autores.",
#             "Pájaros en la Nube es un proyecto de la Fundación Ibercivis y el I3A – Instituto de Inavestigación en Ingeniría de Aragón, y cuenta con el apoyo de la FECYT – Fundación Española para la Ciencia y la Tecnología – Ministerio de Ciencia e Innovación. Además, el proyecto cuenta con la colaboración de los Fablabs de Madrid (medialab Prado), Barcelona, Sant Cugat del Vallés, Valencia, Sevilla y Zaragoza (Laboratorios CESAR en Etopia), junto a las comunidades TTN de Madrid, Barcelona, Valencia, Sevilla y Zaragoza."
#         ],
#         "keywords": [
#             "Pájaros en la Nube",
#             "ESDA – Escuela Superior de Diseño de Aragón",
#             "A través de este documento podéis conocer el proceso de diseño de la caseta y proponer actividades en el aula relacionadas con el prototipado y diseño industrial.",
#             "Pájaros en la Nube",
#             "Fundación Ibercivis",
#             "I3A – Instituto de Inavestigación en Ingeniría de Aragón",
#             "FECYT – Fundación Española para la Ciencia y la Tecnología",
#             "Fablabs de Madrid (medialab Prado), Barcelona, Sant Cugat del Vallés, Valencia, Sevilla y Zaragoza (Laboratorios CESAR en Etopia), junto a las comunidades TTN de Madrid, Barcelona, Valencia, Sevilla y Zaragoza."
#         ]
#     },
#     {
#         "name": "UNIDAD DIDÁCTICA ODOURCOLLECT 2021",
#         "url": "https://ciencia-ciudadana.es/unidad-didactica-odourcollect-2021/",
#         "abstract": [
#             "OdourCollect es un proyecto de ciencia ciudadana sobre contaminación odorífera que convierte a estudiantes – y a sus familias, vecindario y ¡quienes quieran unirse! – en investigadores/as ambientales que exploran su ciudad para monitorizar los olores de su entorno.",
#             "A través de esta guía didáctica los estudiantes podrán descubrir cómo recolectar y categorizar olores a través del mejor de los sensores: tu nariz. Al mismo tiempo, estarán participando en un proyecto de investigación científica real.",
#             "Los tres ingredientes principales de la ciencia ciudadana son la investigación científica, la participación y la educación. Además de facilitar la adquisición de nuevos conocimientos y habilidades científicas, la ciencia ciudadana fomenta un cambio de actitud hacia la ciencia, ya que demuestra que todos/as podemos participar de diversos modos en la generación de conocimiento científico y contribuir en la resolución de problemas comunes. ¿Cómo? Proporcionando datos, analizándolos, favoreciendo nuevas herramientas para los/as investigadores/as, planteando nuevas preguntas y co-creando una nueva cultura científica."
#         ],
#         "keywords": [
#             "OdourCollect",
#             "ciencia ciudadana",
#             "investigación científica",
#             "participación",
#             "educación"
#         ]
#     },
#     {
#         "name": "OPEN SCIENCE, OPEN ISSUES",
#         "url": "https://ciencia-ciudadana.es/open-science-open-issues/",
#         "abstract": [
#             "Este libro ofrece las contribuciones de investigadores de diferentes áreas de estudio y países, con un significativo papel en la ciencia abierta y colaborativa.",
#             "Las cuestiones en torno a la ciencia abierta están ganando terreno no sólo en los entornos institucionales de la ciencia, la tecnología y la innovación, sino también en otros contextos que, hasta ahora, se mantenían separados. Como resultado, se están movilizando otros grupos sociales como interlocutores de las prácticas científicas. ",
#             "Esta publicación busca ofrecer una visión general de temas y cuestiones que trazan e impregnan la ciencia actual desde diferentes perspectivas y puntos de vista. Por encima de todo, los editores y autores buscan una mayor reflexión para fomentar nuevas formas de producción y circulación del conocimiento. ",
#             "El libro está orientado no sólo al mundo académico, sino también a todos los actores sociales que se preocupan por la democratización del conocimiento y la información.",
#             "El libro es el resultado de los debates realizados en el Seminario Internacional “Ciência Aberta, Questões Abertas”1, realizado en 2014 en Rio de Janeiro, por el Instituto Brasileiro de Informação em Ciência e Tecnologia (IBICT), la Open Knowledge Brasil (OKBr), la Universidade Federal do Estado do Rio de Janeiro (Unirio) y el Laboratório Interdisciplinar sobre Informação e Conhecimento (Liinc).",
#             "Editores: Sarita Albagli, Maria Lucia Maciel & Alexandre Hannud Abdo",
#             "Año: 2015",
#             "Editorial: IBICT UNIRIO"
#         ],
#         "keywords": [
#             "Editores:",
#             "Año:",
#             "Editorial:",
#             "aquí"
#         ]
#     },
#     {
#         "name": "GUÍA DE LAS ESPECIES EXÓTICAS E INVASORAS DE LOS RÍOS, LAGOS Y ESTUARIOS DE LA PENÍNSULA IBÉRICA",
#         "url": "https://ciencia-ciudadana.es/guia-especies-exoticas-e-invasoras/",
#         "abstract": [
#             "Esta Guía ha sido realizada en el marco del proyecto LIFE INVASAQUA (LIFE17 GIE/ES/000515) Aquatic Invasive Alien Species of Freshwater and Estuarine Systems: Awareness and Prevention in the Iberian Peninsula, financiado por el Programa LIFE de la Comisión Europea.",
#             "Edición y coordinación de la obra: Frederic Casals y Jorge Rubén Sánchez-González\nRevisión científica: Filipe Ribeiro, Pedro M. Anastácio, Miguel Morgado-Santos",
#             "Diseño iconografías y portada: Alfonso Nombela Gómez (MNCN-CSIC)",
#             "Edita: Sociedad Ibérica de Ictiología",
#             "Descargar PDF aquí."
#         ],
#         "keywords": [
#             "LIFE INVASAQUA",
#             "Programa LIFE de la Comisión Europea",
#             "Edición y coordinación de la obra:",
#             "Revisión científica:",
#             "Diseño iconografías y portada:",
#             "Edita:"
#         ]
#     },
#     {
#         "name": "MINI-GUÍAS ARANZADI DE NATURALEZA",
#         "url": "https://ciencia-ciudadana.es/mini-guias-aranzadi-de-naturaleza/",
#         "abstract": [],
#         "keywords": []
#     },
#     {
#         "name": "LA GESTIÓN ÉTICA DE LOS DATOS",
#         "url": "https://ciencia-ciudadana.es/la-gestion-etica-de-los-datos/",
#         "abstract": [
#             "Cada vez más, actores públicos y privados se plantean cómo escalar su impacto a través del uso de la tecnología. Al mismo tiempo, el uso y gestión de los datos personales de millones de personas preocupa a los ciudadanos y existe un sentimiento de urgencia sobre la necesidad de proteger la seguridad y privacidad de los datos usados. ¿Qué medidas se pueden tomar y cuál es el riesgo de no tomarlas? ¿Cómo puede el sector público gestionar los datos de forma responsable? Este documento ofrece marcos de referencia sobre la gestión ética de datos y sobre la importancia del consentimiento, un compendio de mejores prácticas y una hoja de ruta con pasos concretos para una gestión responsable de datos por parte del sector público.",
#             "DOI: http://dx.doi.org/10.18235/0001623",
#             "Autores: Buenadicha Sánchez, César; Galdon Clavell, Gemma; Hermosilla, María; Loewe, Daniel; Pombo, Cristina"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "UNIDAD DIDÁCTICA DE CITIES AT NIGHT",
#         "url": "https://ciencia-ciudadana.es/unidad-didactica-de-cities-at-night/",
#         "abstract": [
#             "Como parte del desarrollo del proyecto de ciencia ciudadana Cities at Night, el equipo del proyecto ha elaborado una unidad didáctica destinada a complementar en el aula los conocimientos obtenidos por los alumnos de educación secundaria que se han unido y participado en el proyecto.",
#             "La Unidad Didáctica es una propuesta para trabajar en el aula con alumnos de tercero y cuarto de secundaria, la localización de fuentes de la contaminación lumínica a través del proyecto de ciencia ciudadana Cities at Night.",
#             "Presenta contenidos generales sobre la contaminación lumínica, sus tipos y los efectos negativos de la iluminación artificial nocturna, para explicar después el modo más eficiente de instalar fuentes de iluminación que minimicen estos efectos. ",
#             "Posteriormente se presenta el proyecto Cities at Night, sus objetivos y su relación con la ciencia ciudadana, junto a unas actividades sugeridas que se adaptan al nivel del alumnado. Por último, se indican algunos enlaces para ampliar información, tanto para los docentes como para los estudiantes. ",
#             "Pretendemos presentar unos contenidos que se pueden implementar en el aula, y una guía para que tanto el alumnado como los docentes puedan participar en este proyecto de ciencia ciudadana.",
#             "Los proyectos de ciencia ciudadana se construyen con la aportación de muchas personas. Investigadores, divulgadores y voluntarios de todo tipo contribuyen con sus aportaciones para que el proyecto crezca generando una utilidad para la ciencia y la sociedad."
#         ],
#         "keywords": [
#             "Cities at Night",
#             "trabajar en el aula con alumnos de tercero y cuarto de secundaria",
#             "Cities at Nigh",
#             "contenidos generales sobre la contaminación lumínica, sus tipos y los efectos negativos de la iluminación artificial nocturna",
#             "el proyecto Cities at Night",
#             "contenidos que se pueden implementar en el aula",
#             "Los proyectos de ciencia ciudadana",
#             "El material está publicado bajo licencia Creative Commons CC BY-SA 4.0 ES, de acceso libre y gratuito, pudiendo ser compartido, copiado y modificado, respetando siempre su autoría."
#         ]
#     },
#     {
#         "name": "GUÍA DIDÁCTICA VIGILANTES DEL AIRE",
#         "url": "https://ciencia-ciudadana.es/guia-didactica-vigilantes-del-aire/",
#         "abstract": [
#             "La Unidad didáctica del proyecto Vigilantes del Aire es un material educativo apto para cualquier nivel de formación -infantil, primaria y secundaria-, para ser utilizado en el aula o en familia y así poder conocer mejor la contaminación del aire que se estudia gracias a los participantes en #VigilantesDelAire.",
#             "La guía es gratuita y abierta, y se puede utilizar en el aula o en familia, total o parcialemente, o modificarla o ampliarla siemrpe que se cite a sus autores correctamente."
#         ],
#         "keywords": [
#             "La Unidad didáctica del proyecto Vigilantes del Aire es un material educativo",
#             "para ser utilizado en el aula o en familia",
#             "guía es gratuita y abierta"
#         ]
#     },
#     {
#         "name": "CIÉNCIA CIUTADANA A LES BIBLIOTEQUES",
#         "url": "https://ciencia-ciudadana.es/articulo-ciencia-ciutadana-a-les-biblioteques/",
#         "abstract": [
#             "Autores: Perelló, Josep; Bonhoure, Isabelle; Cigarini, Anna; Vicens, Julià.",
#             "El Laboratorio de Ciencia Ciudadana, dirigido a los profesionales de las bibliotecas públicas, quiso descubrir e investigar de forma participativa el potencial de las bibliotecas públicas como espacios donde generar nuevo conocimiento con y para la ciudadanía. Desde el mes de noviembre de 2018 hasta junio de 2019, veintidós cinco bibliotecas han participado en cinco sesiones teórico-prácticas que ofrecen una visión actualizada de la ciencia ciudadana en todo el mundo y han planteado el debate sobre cómo puede implicarse una biblioteca municipal. La publicación recoge estas reflexiones colectivas sobre las razones para introducir la Ciencia Ciudadana en las bibliotecas y los beneficios que puede aportar en este contexto a las personas, a las comunidades ya los propios equipamientos culturales. La formación ha servido también para capacitar a los y las profesionales participantes como mediadores entre ciudadanía y ciencia."
#         ],
#         "keywords": [
#             "El Laboratorio de Ciencia Ciudadana",
#             "reflexiones colectivas sobre las razones para introducir la Ciencia Ciudadana en las bibliotecas y los beneficios que puede aportar en este contexto a las personas, a las comunidades ya los propios equipamientos culturales",
#             "las bibliotecas han seleccionado diez proyectos de ciencia ciudadana que están actualmente en funcionamiento y han imaginado cómo sería su implantación en su municipio, adaptándose a las particularidades culturales y socio de su espacio, barrio y población"
#         ]
#     },
#     {
#         "name": "UNIDAD DIDÁCTICA: «ODOURCOLLECT: CIENCIA CIUDADANA PARA MONITORIZAR LA CONTAMINACIÓN ODORÍFERA»",
#         "url": "https://ciencia-ciudadana.es/disponible-la-unidad-didactica-ciencia-ciudadana-para-monitorizar-la-contaminacion-odorifera/",
#         "abstract": [
#             "El proyecto de ciencia ciudadana OdourCollect pone a disposición de docentes de todo el país una unidad didáctica destinada al alumnado de educación secundaria,  y que tiene como objetivo crear conciencia ambiental sobre la contaminación por olor, uno de los problemas mediomabientales más importantes que acucian a la ciudadanía en todo el mundo. A través de esta unidad didáctica alumnos y alumnas:",
#             "Como docentes, os animamos a descargar la unidad didáctica y a utilizarla en vuestras clases con vuestros alumnos. Podéis descargar la unidad didáctica haciendo en el enlace que os proporcionamos a continuación: ",
#             "Con la unidad didáctica y el apoyo de Odourcollect, proyecto de ciencia ciudadana sobre la contaminación odorífera, alumnos y alumnas – y sus familias, vecindario y quienes quieran unirse -podrán participar como investigadores ambientales que identifiquen y localicen los olores en su entorno o ciudad. Además, conocerán los fundamentos de la ciencia ciudadana y contribuirán al bienestar de sus comunidades. La unidad didáctica está publicada bajo licencia CC BY-SA 3.0 ES, así el docente puede:"
#         ],
#         "keywords": [
#             "OdourCollect",
#             "Como docentes, os animamos a descargar la unidad didáctica y a utilizarla en vuestras clases con vuestros alumnos. Podéis descargar la unidad didáctica haciendo en el enlace que os proporcionamos a continuación: ",
#             "Odourcollect",
#             "Compartir",
#             "Adaptar",
#             "Reconocimiento",
#             "CompartirIgual"
#         ]
#     },
#     {
#         "name": "EXPERIMENTOS MEMP: UN PROYECTO DE INVESTIGACIÓN Y DIVULGACIÓN SOBRE EL AGUA",
#         "url": "https://ciencia-ciudadana.es/experimentos-memp-un-proyecto-de-investigacion-y-divulgacion-sobre-el-agua/",
#         "abstract": [
#             "«Somos un grupo formado por cuatro alumnas de 3o ESO del colegio Jesús-María. Nuestro grupo se llama Experimentos MEMP. Desarrollamos experimentos usando el agua y pruebas para demostrar y explicar sus propiedades. Además, hacemos investigaciones sobre el agua en el mundo.",
#             "Este curso hemos participando en el proyecto de Ciencia Ciudadana que lleva a cabo la Fundación Ibercivis, con el nombre de AQUA. Todos los alumnos de 3o y 4o de ESO estuvimos tomando datos sobre algunos parámetros de calidad del agua que encontramos en nuestros hogares. Utilizando un Kit, medimos el pH del agua, la concentración de cloro y, además, la turbidez, el olor y sabor.",
#             "También fuimos a la Facultad de Ciencias de la Universidad de Burgos acompañadas del profesor. Previamente recogimos muestras de agua de distintos puntos de la ciudad, ríos y fuentes, a fin de analizar distintos parámetros del agua y comparar su concentración en ciertos iones. (…)»",
#             " ",
#             "Autoras: Miguel Ángel Queiruga Dios (director), Mafalda Martins Dos Santos (coordinadora), María Fuster Cuesta, Paola Arranz Alonso, Helena Cardo Alegre.",
#             "Publicado bajo licencia Creative Commons."
#         ],
#         "keywords": [
#             "Autoras:"
#         ]
#     },
#     {
#         "name": "GUÍA DE RECOMENDACIONES PARA PROYECTOS STEAM",
#         "url": "https://ciencia-ciudadana.es/guia-de-recomendaciones-para-proyectos-steam/",
#         "abstract": [
#             "«Presentamos esta guía de recomendaciones como resultado del trabajo colaborativo entre Innobasque y EDE Fundazioa desarrollado a lo largo de 2017 en el contexto del proyecto Espacio STEAM. Una iniciativa en la que han participado cincuenta organizaciones y doce ponentes relevantes, y que ha sido articulada en seis conferencias formativas, seis talleres de creación colectiva y la producción de esta guía. Espacio STEAM nació con vocación de involucrar a los agentes de la educación no formal en el fomento de la Educación STEAM y de la cultura científica, tecnológica y de la innovación, pero desde una perspectiva colaborativa. De esta manera, se concibió como un espacio de aprendizaje compartido donde se conectaba a las organizaciones de la educación no formal con entidades científico-tecnológicas.»"
#         ],
#         "keywords": [
#             "Espacio STEAM",
#             "cultura científica, tecnológica y de la innovación"
#         ]
#     },
#     {
#         "name": "CITIZEN SCIENCE IN SCHOOL",
#         "url": "https://ciencia-ciudadana.es/citizen-science-in-school-paper/",
#         "abstract": [
#             "Este artículo se encuentra contenido en la publicación Hands-on Science. Advancing Science. Improving Education: http://www.hsci.info/hsci2018/images/pdfs/eBookHSCI2018.pdf"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: EL AIRE. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-el-aire-la-aventura-de-aprender/",
#         "abstract": [
#             "«Inspira hondo hasta llenar los pulmones. Contén la respiración. Expira. Durante estos segundos, millones de partículas y de gases han entrado y salido por tu cuerpo. Necesitamos el aire para respirar, igual que casi todos los animales y las plantas. Es nuestro sustento más básico y una de las funciones más automáticas de nuestro organismo. Y sin embargo, en nuestra cultura occidental se ha considerado en los últimos siglos como un espacio vacío, como el opuesto al mundo material. (…)»",
#             " ",
#             "Nerea Calvillo es arquitecta, investigadora en el Centre for Interdisciplinary Methodologies (Universidad de Warwick), fundadora de C+ arquitectos y del proyecto In the Air.",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: LAS COSTAS. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-las-costas-la-aventura-de-aprender/",
#         "abstract": [
#             "«¿Cuándo fue la última vez que paseaste con los pies descalzos por la playa disfrutando de la brisa marina, respirando hondo y dejando volar tu imaginación? En compañía o en soledad… Experiencias como esta nos permiten apreciar el enorme valor de los paisajes que se suceden a lo largo de esa serpenteante línea que se dibuja entre la tierra y el mar. La costa es una frontera mágica que nos reconcilia con el medio ambiente al que, en el fondo, pertenecemos y que compartimos con otros seres vivos. (…)»",
#             " ",
#             "Manuel Borobio Sanchiz y Francisco Castillo Rodríguez, un arquitecto y un geógrafo, dos apasionados de la costa y sus paisajes, convencidos de la importancia de la educación como herramienta de empoderamiento. Dos aprendices con almas de niño que todavía creen que es posible cambiar el mundo.",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: LAS INFRAESTRUCTURAS. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-las-infraestructuras-la-aventura-de-aprender/",
#         "abstract": [
#             "«La capital de Perú, Lima, se asienta sobre una geografía curiosa, en una estrecha franja de desierto entre la cordillera de los Andes y el océano Atlántico. El clima es extraño: salvo El Cairo no hay ciudad en el mundo más árida que Lima, y, sin embargo, sobre la ciudad cuelgan habitualmente nubes de bochornosa humedad tropical. La población de Lima alcanza hoy los nueve millones de habitantes. De ellos, casi dos millones de personas viven en los barrios periféricos de la ciudad, las llamadas barriadas. Las barriadas se extienden sobre terrenos difíciles, entre las arenas del desierto y las primeras pendientes de los Andes, dando pie, cuando llueve, a peligrosos aludes y deslizamientos. Todo ello —la geografía, el clima, la sobrepoblación— ha dificultado la provisión de infraestructuras urbanas básicas en los asentamientos, como carreteras, tendido eléctrico o sistemas de alcantarillado y agua potable. (…)»",
#             " ",
#             "Alberto Corsín Jiménez es antropólogo en el Consejo Superior de Investigaciones Científicas y cofundador de la infraestructura de aprendizajes urbanos libres Ciudad Escuela.",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: EL PAISAJE. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-el-paisaje-la-aventura-de-aprender/",
#         "abstract": [
#             "«Si te asomas a la ventana de tu casa ¿qué ves? Quizá un campo de cereal, quizá un polígono industrial, una carretera, un bosque, un jardín, lo más probable es que otro edificio con ventanas desde donde alguien te observa. Este acto de mirar implica la existencia de un sujeto observador, que se pregunta cosas (tú), y de un objeto que es escudriñado, analizado o simplemente admirado (lo que ves). (…)»",
#             " ",
#             "Jesús Fernández Fernández es arqueólogo, doctor en Historia (Universidad de Oviedo) y autor de diferentes publicaciones científicas relacionadas con la arqueología pública y comunitaria, los paisajes culturales y los Sistemas de Información Geográfica. Es Honorary Research Associate en el Institute of Archaeology de la University College London y fue investigador postdoctoral en la Universidad de Oxford. Coordina varios proyectos de investigación en colaboración con diferentes universidades y desde 2012 es emprendedor social y fundador de un proyecto comunitario en arqueología y museología (La Ponte-Ecomuséu, en Asturias, España).",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar.",
#             "El proyecto LA AVENTURA DE APRENDER se encuentra recogido en el Listado de Proyectos del Observatorio, y puedes informarte sobre él en el siguiente enlace: http://ciencia-ciudadana.es/la-aventura-de-aprender/",
#             " "
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: LAS PESQUERÍAS. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-las-pesquerias-la-aventura-de-aprender/",
#         "abstract": [
#             "«¿Qué es una pesquería? Más que de peces es hablar de personas. Habitualmente cuando hablamos de pesquerías una de las primeras imágenes que se nos viene a la cabeza es la de un extenso banco de peces plateados que surcan las aguas azules. Evidentemente, los recursos marinos son el objeto de las pesquerías, pero son los actores humanos quienes las interviene. Las pesquerías son pescadores y pescadoras que como productores primarios extraen los recursos marinos, casi siempre como una actividad económica (profesionales) y en ocasiones como ocio (lúdicos). En general, en los países industrializados, la pesca profesional suele ser una actividad a tiempo completo, aunque en muchos países, especialmente en vías de desarrollo, la pesca es bien una actividad exclusiva realizada a tiempo parcial bien una actividad temporal que complementa a otras, siendo habitual encontrarnos con binomios del estilo agricultor-pescador, ganadero-pescador, o artesano-pescador. (…)»",
#             " ",
#             "DUARTE VIDAL es educador y antropólogo, especializado en gestión pesquera y economía del mar. Investigador en el Centro Tecnológico del Mar (CETMAR-Galicia) dentro del Área de Socioeconomía de la pesca.",
#             "JUAN FREIRE es biólogo ambiental especializado en gestión de pesquerías y ecosistemas marinos. Decano Académico de la Escuela de Negocios del Tecnológico de Monterrey.",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: LOS BOSQUES. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-los-bosques-la-aventura-de-aprender/",
#         "abstract": [
#             "«El bosque, los bosques… ¿qué imágenes vienen a nuestra mente cuando oímos la palabra bosque? Posiblemente, imaginamos colinas llenas de árboles, con pájaros, flores… quizás algún arroyo de agua asomando a lo lejos… Esta podría ser una de esas imágenes idílicas que a menudo nos muestran los cuadros, las películas o algunas fotos, pero… ¿Qué más? ¿Qué más es un bosque? ¿Realmente todos responden a esta imagen? ¿Son todos los bosques iguales? ¿Es un bosque solo un trozo de hermoso paisaje o esconde algo más? (…)»",
#             " ",
#             "NURIA ALONSO LEAL es Licenciada en Ciencias Ambientales, experta en cooperación internacional, y dedicada en los últimos años a la participación social para la sostenibilidad. Forma parte de la Fundación Entretantos (www.entretantos.org), una entidad sin ánimo de lucro creada por un grupo de personas y entidades que tienen en común su apuesta por la participación ciudadana como herramienta de construcción colectiva y toma de decisiones sobre los asuntos comunes y las políticas públicas.",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: LA MOVILIDAD URBANA. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-la-movilidad-urbana-la-aventura-de-aprender/",
#         "abstract": [
#             "«¿Cómo podemos conseguir que las calles vuelvan a ser un espacio que no se limite al mero desplazamiento, casi siempre motorizado, y recuperen funciones como el disfrute, las relaciones, el juego, la imaginación, etc., junto con nuevas formas de desplazamiento?",
#             "Porque lo cierto es que las calles cada vez se diferencian menos de las carreteras. (…)»",
#             " ",
#             "Las guías RECLAMAR didácticas tienen por objetivo favorecer la puesta en marcha de proyectos colaborativos que conecten la actividad de las aulas con lo que ocurre fuera del recinto escolar.",
#             "El proyecto LA AVENTURA DE APRENDER se encuentra recogido en el Listado de Proyectos del Observatorio, y puedes informarte sobre él en el siguiente enlace: http://ciencia-ciudadana.es/la-aventura-de-aprender/",
#             " "
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: LA PAZ. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-la-paz-la-aventura-de-aprender/",
#         "abstract": [
#             "«Esta guía de «Cómo reclamar la paz» forma parte de una serie de guías que deben servir a cualquiera, pero ante todo a jóvenes de 11 a 18 años, para hacer en grupo trabajos de investigación que contribuyan a salvaguardar y enriquecer los procomunes o bienes comunes, en este caso a fortalecer la voluntad ciudadana de sostener y generar paz. (…)»",
#             "Juan Gutiérrez Cortines. Dr. Ingeniero Caminos, Dr. en Filosofía (Universidad de Hamburgo), experto de tratamiento de conflictos. En 1987 fundó y dirigió hasta 2001 Gernika Gogoratuz, centro de investigación por la paz y tratamiento de conflictos, donde facilitó el paso histórico de reconciliación del Presidente de Alemania –Roman Herzog– entre su país, el Pais Vasco y España, por lo que obtuvo la Cruz del Mérito de Alemania y el Primer Premio de Gernika por la Paz y la Reconciliación. De 1990 a 2000 actuó en una mediación informal de alto nivel en el conflicto vasco. Del 2004 al 2011 ha sido asesor de la Asociacion 11M Afectados del Terrorismo. Desde 2011 coordina en Medialab-Prado un projecto de Memoria y Paz y actualmente es presidente de la Asociación de ámbito internacional Hebras de Paz Viva. E-mail: juanenruta@gmail.com",
#             " ",
#             "El proyecto LA AVENTURA DE APRENDER se encuentra recogido en el Listado de Proyectos del Observatorio, y puedes informarte sobre él en el siguiente enlace: http://ciencia-ciudadana.es/la-aventura-de-aprender/",
#             " ",
#             " "
#         ],
#         "keywords": []
#     },
#     {
#         "name": "RECLAMAR: EL BARRIO. LA AVENTURA DE APRENDER",
#         "url": "https://ciencia-ciudadana.es/reclamar-el-barrio-la-aventura-de-aprender/",
#         "abstract": [
#             "«Reclama tu barrio. O tu pueblo, o tu ciudad, el lugar donde vives y que te vincula en primer lugar con tus conciudadanos. Allí de donde te sientas, o al revés: ese espacio que no termina de ser del todo tuyo, nuestro, es el objeto de esta guía. Apropiarse del espacio a través del reconocimiento del tiempo. Hacer nuestro el barrio a través del sentido que damos a los relatos que nos acercan al pasado. Este pensar históricamente el entorno vuelve sobre nosotros, nos interpela y nos cambia (…)»",
#             "Pablo Sánchez León tiene formación como historiador, es investigador en la Universidad del País Vasco, trabaja sobre temas de historia y memoria desde una perspectiva ciudadana; es también director de Postmetropolis editorial (www.postmetropolis.com)",
#             "Las guías RECLAMAR quieren promover entre la ciudadanía la producción de conocimiento original y contrastado que ayude a entender cómo son y cómo funcionan los bienes comunes.",
#             "El proyecto LA AVENTURA DE APRENDER se encuentra recogido en el Listado de Proyectos del Observatorio, y puedes informarte sobre él en el siguiente enlace: http://ciencia-ciudadana.es/la-aventura-de-aprender/"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "WHITE PAPER ON CITIZEN SCIENCE FOR EUROPE / LIBRO BLANCO DE LA CIENCIA CIUDADANA",
#         "url": "https://ciencia-ciudadana.es/white-paper-on-citizen-science-for-europe/",
#         "abstract": [
#             "El Libro Blanco de la ciencia ciudadana para Europa es un documento estratégico que compila y formula las principales recomendaciones políticas de la comunidad internacional para comprender y encauzar los diversos impactos de la ciencia ciudadana.",
#             " ",
#             "En él se plantean recomendaciones concretas para facilitar la inclusión del conjunto de la sociedad en la ciencia. Reconociendo que la definición está abierta y es dinámica, describe la ciencia ciudadana como «el compromiso del público general en actividades de investigación científica al contribuir activamente a la ciencia con su esfuerzo intelectual o dando soporte al conocimiento con sus herramientas o recursos«. "
#         ],
#         "keywords": [
#             "el compromiso del público general en actividades de investigación científica al contribuir activamente a la ciencia con su esfuerzo intelectual o dando soporte al conocimiento con sus herramientas o recursos",
#             "Socientize",
#             "Instituto de Investigación BIFI ",
#             "Universidad de Zaragoza ",
#             "F",
#             "undación Ibercivis",
#             "7º Programa Marco",
#             "Infraestructuras de Investigación."
#         ]
#     }
# ]

# %%
if (EXPORT_JSON):
    with open('SpanishEducationalResources.json', 'w', encoding='utf-8') as fp:
        json.dump(lista_diccionarios_er, fp,  ensure_ascii=False)

# %% [markdown]
# ### INFORMES

# %%
if (SCRAP_SPANISH):

    #Set up the path to the chrome driver
    driver= webdriver.Chrome('./chromedriver.exe')
    driver.get('https://ciencia-ciudadana.es/category/informes/')

    #Get all the names and links, and store them in a list
    informes = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')
    
    informes_list=[]

    for informe in informes:
        title=informe.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
        link = title.get_attribute('href')

        this_informe={"Title": title.text, "Link": link}
        informes_list.append(this_informe)
        
    #Since there is more than one page   
    num_pages = driver.find_elements_by_xpath('//a[@class="wpv-archive-pagination-link js-wpv-archive-pagination-link page-link"]')
    
    links_pages=[]
    for page in num_pages:
        links_pages.append(page.get_attribute("href"))
    links_pages
    
    #informes_list
    driver.close()

# %%
if (SCRAP_SPANISH):
    driver= webdriver.Chrome('./chromedriver.exe')
    #go to the next pages and do the same
    for i in range(len(links_pages)):
        driver.get(links_pages[i])
        #Get all the reports' names and links and store them in a list
        informes = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')

        for informe in informes:
            title=informe.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
            link = title.get_attribute('href')

            this_informe={"Title": title.text, "Link": link}
            informes_list.append(this_informe)
    driver.close()
    #informes_list

# %%
if (SCRAP_SPANISH):

    driver= webdriver.Chrome('./chromedriver.exe')

    #Create a list of dictionaries
    lista_diccionarios_informes=[]

    #Iterate, for every report in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(informes_list)):
        informes_dict={}

        driver.get(informes_list[i]["Link"])

        informes_dict["name"]=informes_list[i]["Title"]
        informes_dict["url"]=informes_list[i]["Link"]
        
        content=driver.find_element_by_xpath("//div[@class='entry-content']")

        text_list=[]
        sentences = content.find_elements_by_xpath("//p")
        
        for i in range(len(sentences)-4):
            if(sentences[i].text!=""):
                text_list.append(sentences[i].text)

        keywords=[]
        strong=driver.find_elements_by_xpath("//strong")
        for negrita in strong:
            keywords.append(negrita.text)
            
        informes_dict["abstract"]=text_list
        informes_dict["keywords"]=keywords

        lista_diccionarios_informes.append(informes_dict)
        
    driver.close()

    #lista_diccionarios_informes
    jprint(lista_diccionarios_informes)
# Out:
# [
#     {
#         "name": "INFORME DEL OBSERVATORIO DE LA CIENCIA CIUDADANA EN ESPAÑA 2020",
#         "url": "https://ciencia-ciudadana.es/informe-del-observatorio-de-la-ciencia-ciudadana-en-espana-2020/",
#         "abstract": [
#             "Dejamos para su descarga y consulta el informe del Observatorio de la Ciencia Ciudadana en España, que repasa la actividad del Observatorio y los agentes implicados en la ciencia ciudadana – gestores de proyectos, instituciones y científicos ciudadanos- durante el plazo que va desde abril de 2019 a noviembre de 2020.",
#             "Queremos destacar que el trabajo del Observatorio es un trabajo de co-creación realizado con todas y cada una de las personas que hacen ciencia ciudadana en España, sea cual sea su papel. Muchas de esas personas colaboran también directamente en el desarrollo del Observatorio, por ejemplo aportando recursos (educativos o de otro tipo), realizando tareas de comunicación, participando en coloquios, o en entrevistas y artículos, como queda reflejado en el informe. Por eso, sin ser un proyecto de ciencia ciudadana – en el sentido de que su objetivo no es encontrar resultados a una pregunta de investigación – el Observatorio es, cada vez más, un proyecto participativo en torno a la I+D+i, en el que entendemos la cooperación como una clave fundamental. Al igual que en los demás proyectos de Ibercivis – esos sí, de ciencia ciudadana – buscamos trabajar de un modo colaborativo en el que cada persona aporta y recibe, en el que todos nos enriquecemos al construir o mejorar los diversos ámbitos en que nos movemos, incluidos los sistemas – institucionales o no – de ciencia y tecnología, o de investigaciones sociales y humanísticas, o de educación. Buscamos co-crear espacios para generar y compartir conocimiento, espacios en los que se multiplican las sinergias y los agradecimientos mutuos. Confiamos en que esto sea una realidad, corregida y aumentada entre todos. ¡Gracias!",
#             "-De los 77 proyectos de ciencia ciudadana con participación española financiados por los Programas Marco de la Unión Europea hasta la fecha, son 28 los liderados por grupos españoles.\n-Se han financiado proyectos tanto en la línea transversal ciencia con y para la sociedad como en el área sobre desafíos sociales, una de las tres áreas fundamentales (pilares) de Horizonte 2020.\n-Se puede prever el apoyo de Horizonte Europa a la ciencia ciudadana en un número creciente de áreas de investigación, en particular en temas alineados con los Objetivos de Desarrollo Sostenible de la ONU.\n-La ciencia ciudadana española ha estado presente en los acontecimientos más relevantes del panorama europeo e internacional.",
#             "-La Estrategia Española de Ciencia y Tecnología incluye la ciencia ciudadana entre sus cuatro principios básicos para apoyar la investigación y la innovación nacional.\n-La convocatoria de ayudas de FECYT correspondiente a esta edición del Observatorio añadió la ciencia ciudadana entre sus líneas de actuación.\n-Una gran parte de la infinidad de impactos científicos de la ciencia ciudadana queda reflejada en el número creciente de publicaciones en revistas indexadas.\n-Los proyectos de ciencia ciudadana en España – cada vez más diversos en temáticas, metodologías, alcance, inclusividad – generan importantes impactos sociales, ambientales, educativos y políticos, junto a los científicos.",
#             "-Las iniciativas recogidas en la web del Observatorio son actualmente 287.\n-Se ha enriquecido la sección de entrevistas con la colaboración de 23 personas aportando su visión y experiencia como participantes, gestores, comunicadores, educadores o investigadores en proyectos de ciencia ciudadana.\n-Se continúa con la publicación semanal de artículos – 83 en esta edición – en colaboración con Tercer Milenio Heraldo.\n-Se han realizado siete coloquios online con la colaboración de cerca de 60 personas panelistas, sobre temas en relación con proyectos de ciencia ciudadana como salud, educación, ética, comunicación, ciencia abierta, covid-19 y ciudadanía.\n-El Observatorio ha estado presente en más de 20 eventos nacionales e internacionales.",
#             "-La relevancia del mundo maker en ciencia y tecnología se ha hecho aún más visible a través de Coronavirus Makers, una iniciativa capaz de reunir a más de 15.000 personas en España para combatir la Covid-19 desde sus casas.\n-La respuesta ciudadana ha sido de tipo social – con la ayuda mutua como clave – y de tipo tecno-logístico, pudiendo fabricarse equipos de protección individual para los sectores sociales que los necesitasen.\n-Los ecosistemas de conocimiento tecnológico distribuido que caracterizan el mundo maker – donde la documentación abierta y la cooperación son claves – fomentan la investigación académica, la creación de empresas y, fundamentalmente, el acercamiento de la tecnología de manufactura digital a hogares y centros de enseñanza.",
#             "Además, dejamos disponible el vídeo con la presentación del informe, que tuvo lugar el pasado día 17 de diciembre."
#         ],
#         "keywords": [
#             "trabajo de co-creación",
#             "proyecto participativo",
#             "cooperación",
#             "todos nos enriquecemos",
#             "co-crear espacios para generar y compartir conocimiento",
#             "presentación del informe"
#         ]
#     },
#     {
#         "name": "PLAN NACIONAL DE ADAPTACIÓN AL CAMBIO CLIMÁTICO 2021-2030",
#         "url": "https://ciencia-ciudadana.es/plan-nacional-de-adaptacion-al-cambio-climatico-2021-2030/",
#         "abstract": [
#             "El Consejo de Ministros, a propuesta del Ministerio para la Transición Ecológica y el Reto Demográfico, aprobó, el 22 de septiembre de 2020, el segundo Plan Nacional de Adaptación al Cambio Climático (PNACC) 2021-2030, una herramienta fundamental hacia la reconstrucción verde de España cuyo principal objetivo es construir un país menos vulnerable, más seguro y resiliente a los impactos y riesgos del cambio climático, capaz de anticipar, de responder y de adaptarse a un contexto de clima cambiante.",
#             "Enlace para descargar PDF aquí."
#         ],
#         "keywords": [
#             "una herramienta fundamental hacia la reconstrucción verde de España cuyo principal objetivo es construir un país menos vulnerable, más seguro y resiliente a los impactos y riesgos del cambio climático, capaz de anticipar, de responder y de adaptarse a un contexto de clima cambiante.",
#             "aquí."
#         ]
#     },
#     {
#         "name": "TENDENCIAS RECIENTES EN LAS POLÍTICAS CIENTÍFICAS DE CIENCIA ABIERTA Y ACCESO ABIERTO EN IBEROAMÉRICA",
#         "url": "https://ciencia-ciudadana.es/ciencia_abierta_clacso_fcarolina/",
#         "abstract": [
#             "El propósito general del informe busca reconstruir y analizar el estado de las investigaciones y las políticas científicas en acceso abierto, datos abiertos de investigación y ciencia abierta en Iberoamérica e indagar su incidencia en la evaluación de trayectorias investigativas, publicaciones científicas e indicadores de impacto. Con ello, CLACSO y la Fundación Carolina persiguen contribuir desde el desarrollo de conocimientos locales y situados al tratamiento y posible resolución de los grandes desafíos planteados por los Objetivos de Desarrollo Sostenible de la Agenda 2030.",
#             "Autoras: Dominique Babini & Laura Rovelli",
#             "El PDF del documento puede descargarse aquí.",
#             " "
#         ],
#         "keywords": [
#             "reconstruir y analizar el estado de las investigaciones y las políticas científicas en acceso abierto, datos abiertos de investigación y ciencia abierta en Iberoamérica",
#             "evaluación de trayectorias investigativas, publicaciones científicas e indicadores de impacto",
#             "CLACSO y la Fundación Carolina",
#             "aquí."
#         ]
#     },
#     {
#         "name": "EECTI: ESTRATEGIA ESPAÑOLA DE CIENCIA, TECNOLOGÍA E INNOVACIÓN2021-2027",
#         "url": "https://ciencia-ciudadana.es/eecti-estrategia-espanola-de-ciencia-tecnologia-e-innovacion2021-2027/",
#         "abstract": [
#             "La Estrategia Española de Ciencia, Tecnología e Innovación 2021-2027 (EECTI 2021-2027) es el instrumento de base para consolidar y reforzar el Sistema de Ciencia, Tecnología e Innovación (SECTI) en los próximos siete años. La ECCTI 2021-2027 está específicamente diseñada para facilitar la articulación de nuestra política de I+D+I con las políticas de la Unión Europea, teniendo en cuenta los reglamentos aprobados o en curso, para así poder aprovechar de la mejor manera posible las sinergias entre los programas. En este aspecto la estrategia añade elementos que pretenden promover también la máxima coordinación entre la planificación y programación Estatal y Autonómica."
#         ],
#         "keywords": [
#             "La Estrategia Española de Ciencia, Tecnología e Innovación 2021-2027 (EECTI 2021-2027)"
#         ]
#     },
#     {
#         "name": "INFORME DEL OBSERVATORIO DE LA CIENCIA CIUDADANA EN ESPAÑA 2018",
#         "url": "https://ciencia-ciudadana.es/informe-del-observatorio-de-la-ciencia-ciudadana-en-espana-2018/",
#         "abstract": [],
#         "keywords": [
#             "Fundación Ibercivis"
#         ]
#     },
#     {
#         "name": "INFORME COTEC 2020",
#         "url": "https://ciencia-ciudadana.es/informe-cotec-2020/",
#         "abstract": [
#             "La Fundación Cotec para la innovación es una organización privada sin ánimo de lucro cuya misión es promover la innovación como motor de desarrollo económico y social. Cotec cuenta con cerca de 90 patronos, entre empresas privadas y administraciones de los ámbitos regional y local. S.M. el Rey Felipe VI es el Presidente de Honor. Desde 2001 existe además Cotec Italia, y desde 2003, Cotec Portugal, que confieren un carácter internacional al impulso a la innovación que promueve Cotec.",
#             "La Fundación Cotec se distinguió desde 1990 por realizar una intensa labor al servicio de la innovación tecnológica entre las empresas españolas. En el cumplimiento de esa misión, Cotec destacó principalmente en dos actividades: servir de observatorio de la I+D+I en España, y proporcionar análisis y consejos en materia de innovación, tecnología y economía.",
#             "En 2015 Cotec decidió ampliar sus retos para convertirse en un verdadero agente de cambio que contribuya al desarrollo de la economía y la sociedad española partiendo de una definición más ambiciosa del concepto de innovación."
#         ],
#         "keywords": [
#             "Fundación Cotec"
#         ]
#     },
#     {
#         "name": "INFORME CIENTÍFICO DE VIGILANTES DEL CIERZO 2017",
#         "url": "https://ciencia-ciudadana.es/informe-cientifico-de-vigilantes-del-cierzo-2017/",
#         "abstract": [
#             "Vigilantes del Cierzo ha sido uno de los proyectos de ciencia ciudadana que introdujo la utilización de biosensores para la medición de la calidad del aire en España, a la vez que se introducía la participación activa de los ciudadanos en su desarrollo."
#         ],
#         "keywords": [
#             "Vigilantes del Cierzo",
#             "Roeland Samson"
#         ]
#     },
#     {
#         "name": "INFORME CIENTÍFICO DE VIGILANTES DEL AIRE 2019/2020",
#         "url": "https://ciencia-ciudadana.es/informe-cientifico-de-vigilantes-del-aire-2019-2020/",
#         "abstract": [
#             "Vigilantes del Aire es un proyecto de ciencia ciudadana en el que se utilizan plantas de fresa como bioindicadores de la concentración de metales pesados en el aire. Durante su edición de 2019, se repartieron 5000 plantas a ciudadanos participantes de toda españa que con sus cuidados han contribuido a monitorizar el estado del aire de sus pueblos y ciudades.",
#             "El proyecto es una iniciativa de la Fundación Ibercivis y el Instituto Pirenaico de Ecología, y cuenta con el apoyo de la FECYT, Fundación Española para la Ciencia y la Tecnología – Ministerio de Ciencia e Innovación. Además, al proyecto se han unido distintas instituciones regionales que han colaborado en el reparto de las plantas en sus zonas, convirtiéndose en embajadores regionales del proyecto: Fundación descubre en Granada, Open Science Cambre en La Coruña, Ideas For Change en Barcelona, Ubu Verde- Universidad de Burgos y CEA Gasteiz en Vitoria.",
#             "El desarrollo del proyecto, que continúa en 2020, puede seguirse en su página web https://vigilantesdelaire.ibercivis.es",
#             "En este informe presentan los resultados de la monitorización de la calidad del aire en áreas urbanas españolas a través de Vigilantes del Aire, un proyecto de ciencia ciudadana que utiliza macetas de fresa como biosensores de la calidad del aire.",
#             "En concreto, utilizamos las propiedades magnéticas de la contaminación metálica acumulada en hojas de fresa (Fragaria vesca L.), como bioindicador de la contaminación atmosférica."
#         ],
#         "keywords": [
#             "Vigilantes del Aire",
#             "los resultados de la monitorización de la calidad del aire en áreas urbanas españolas a través de Vigilantes del Aire",
#             "las propiedades magnéticas de la contaminación",
#             "1391 muestras que han sido previamente situadas y cuidadas por científicos ciudadanos",
#             "Barcelona, Vitoria, Zaragoza, Burgos, Granada y Cambre-A Coruña"
#         ]
#     },
#     {
#         "name": "INFORME: PROGRAMAS DE SEGUIMIENTO DE AVIFAUNA Y GRUPOS DE TRABAJO 2019. SEO/BIRDLIFE",
#         "url": "https://ciencia-ciudadana.es/informe-programas-de-seguimiento-de-avifauna-y-grupos-de-trabajo-2019-seo-birdlife/",
#         "abstract": [
#             "«En estos momentos, SEO/BirdLife mantiene activos 13 programas de seguimiento de avifauna y de sus hábitats, además de 5 grupos de trabajo también con base de funcionamiento en ciencia ciudadana, que movilizan varios miles de colaboradores y que generan millones de registros anualmente. Estos datos son demandados y utilizados por la administración de forma habitual porque permiten dar cumplimiento a  numerosas obligaciones establecidas por leyes, convenios y normativas nacionales e internacionales.» Fuente: https://www.seo.org/ciencia-ciudadana/",
#             "En la web de SEO/BirdLife, en su sección específica sobre ciencia ciudadana, pueden encontrarse valiosas herramientas de participación así como publicaciones anuales sobre los resultados de los programas de seguimiento y grupos de trabajo. Aquí se presenta el informe correspondiente al año 2019, descargable más abajo."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "INFORME: PERCEPCIÓN SOCIAL DE LA CIENCIA Y LA TECNOLOGÍA EN ESPAÑA 2018. FECYT",
#         "url": "https://ciencia-ciudadana.es/percepcion-social-de-la-ciencia-y-la-tecnologia-en-espana-2018/",
#         "abstract": [],
#         "keywords": []
#     },
#     {
#         "name": "DITOS POLICY BRIEF ON DIYBIO",
#         "url": "https://ciencia-ciudadana.es/ditos-policy-brief-on-diybio/",
#         "abstract": [
#             "This policy brief assesses the potential and challenges of “Do-It-Yourself Biotechnology” (DIYBio) for the progression of open science and responsible research and innovation (RRI). It makes recommendations to the European Commission as to how it can integrate DIYBio into existing science funding mechanisms and regulatory directives, thereby maximising benefits for European stakeholders. ",
#             "DIYBio activities are conducted in various private and public laboratories outside of traditional academic or corporate institutions and are therefore outside the scope of current policy. The full spectrum of DIYBio activities is also much broader than what is currently understood as Citizen Science.",
#             " ",
#             "Este Policy Brief evalúa el potencial y los retos de la «biotecnología hágalo usted mismo» (DIYBio) para el progreso de la ciencia abierta y la investigación e innovación responsable (RRI). Hace recomendaciones a la Comisión Europea sobre cómo puede integrar el DIYBio en los mecanismos de financiación de la ciencia y en las directivas reguladoras existentes, maximizando así los beneficios para las partes interesadas europeas. "
#         ],
#         "keywords": []
#     },
#     {
#         "name": "METRICS AND INDICATORS OF RESPONSIBLE RESEARCH AND INNOVATION",
#         "url": "https://ciencia-ciudadana.es/5275-2/",
#         "abstract": [
#             "«This deliverable is the second of two reports within Task 3 of the MoRRI project. In short, the objective of Task 3 has been to construct, identify, and specify relevant metrics and indicators to be used in the subsequent RRI monitoring. Whereas the previous report (D.3.1) synthesised and assessed existing indicators and secondary data, this report (D.3.2) will [a] pin down the final, core set of RRI indicators, [b] provide detailed descriptions of each indicator, and [c] specify the primary and secondary data and procedures guiding the data-collection in Task 4. It should be noted that the indicators selected and presented in this report tap into RRI practices that could be used for monitoring the evolution of RRI across Europe. Later tasks of the MoRRI project will develop indicators focusing specifically on the societal benefits and impacts of such RRI practices. (…)«",
#             " "
#         ],
#         "keywords": []
#     },
#     {
#         "name": "INFORME: METRICS AND INDICATORS OF RESPONSIBLE RESEARCH AND INNOVATION",
#         "url": "https://ciencia-ciudadana.es/informe-metrics-and-indicators-of-responsible-research-and-innovation/",
#         "abstract": [],
#         "keywords": []
#     },
#     {
#         "name": "INFORME: ENDORSING THE GERMAN GREEN PAPER ON CITIZEN SCIENCE",
#         "url": "https://ciencia-ciudadana.es/informe-endorsing-the-german-green-paper-on-citizen-science/",
#         "abstract": [
#             "«The German research and capacity building project “Citizens create knowledge, knowledge creates citizens” (Bürger schaffen Wissen, Wissen schafft Bürger – GEWISS) has elaborated the Green Paper “Citizen Science Strategy 2020 for Germany”. A series of stakeholder round tables, workshops and information materials have fed in to the development of the Green Paper, which is now publically consulted before being submitted to the Federal Ministry of Education and Research. The project is funded by the ministry and has been carried out by a consortium of member institutes of the Helmholtz and Leibniz associations in cooperation with partners.«"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "REPORT: «CITIZEN SCIENCE FOR ENVIRONMENTAL POLICY»",
#         "url": "https://ciencia-ciudadana.es/paper-citizen-science-for-environmental-policy/",
#         "abstract": [
#             "«Citizen science is the non-professional involvement of volunteers in the scientific process, whether in the data collection phase or in other phases of the research. Citizen science is a powerful tool for environmental management that has the potential to inform an increasingly complex environmental policy landscape and to meet the growing demands from society for more participatory decision-making. While there is growing interest from international bodies and national governments in citizen science, however the evidence that it can successfully contribute to environmental policy development, implementation, evaluation or compliance remains scant. Central to elucidating this question is a better understanding of the benefits delivered by citizen science, that is to determine to what extent these benefits can contribute to environmental policy, and to establish whether projects that provide policy support also co-benefit science and encourage meaningful citizen engagement. The aim of this study was to provide the European Commission with an evidence base of citizen science activities that can support environmental policies in the European Union (EU). The first objective was to develop an inventory of citizen science projects relevant for environmental policy and assess how these projects contribute to the Sustainable Development Goals (SDGs) set by the United Nations (UN) General Assembly. To this end, a desk-research and an EU-wide survey were used to identify 503 citizen science projects of relevance to environmental policy. The second objective was to assess the conditions under which citizen science can best support environmental policy, through the selection and analysis of a sample of citizen science projects. This was followed by an in-depth analysis of 45 projects along 94 project attributes. Subsequently, this analysis provided the foundation for making a series of recommendations to leverage the contribution of citizen science to environmental policy.«"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "INFORME: ‘DO IT YOURSELF BIOTECHNOLOGY’ (DIYBIO) FOR OPEN, INCLUSIVE, RESPONSIBLE BIOTECHNOLOGY",
#         "url": "https://ciencia-ciudadana.es/informe-do-it-yourself-biotechnology-diybio-for-open-inclusive-responsible-biotechnology/",
#         "abstract": [
#             "«This policy brief assesses the potential and challenges of “Do-It-Yourself Biotechnology” (DIYBio) for the progression of Open Science and Responsible Research and Innovation (RRI). It makes recommendations to the European Commission as to how it can integrate DIYBio into existing science funding mechanisms and regulatory directives, thereby maximising benefits for European stakeholders.",
#             "DIYBio activities are conducted in various private and public laboratories outside of traditional academic or corporate institutions and are therefore outside the scope of current policy. The full spectrum of DIYBio activities is also much broader than what is currently understood as Citizen Science.«"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "INFORME: OPEN DIGITAL SCIENCE",
#         "url": "https://ciencia-ciudadana.es/informe-open-digital-science/",
#         "abstract": [
#             "«Are there radically different scientific practices emerging based on digital technologies? What are they? How are they changing the relation of science and society?",
#             "Open Digital Science (ODS) and Open Science describe new and open practices in science, research and innovation that make extensive use of digital technologies. The use of digital technologies facilitates openness regarding data, methods, results, actors or publications with an emphasis on scalability of the approach in terms of data, access or computation. (…)»"
#         ],
#         "keywords": []
#     },
#     {
#         "name": "EL PROYECTO PICA SOBRE LA IMAGEN DE LA CIENCIA: INFORME DE RESULTADOS",
#         "url": "https://ciencia-ciudadana.es/el-proyecto-pica-sobre-la-imagen-de-la-ciencia-informe-de-resultados/",
#         "abstract": [],
#         "keywords": []
#     },
#     {
#         "name": "INFORME DEL OBSERVATORIO DE LA CIENCIA CIUDADANA EN ESPAÑA 2017",
#         "url": "https://ciencia-ciudadana.es/informe-del-observatorio-de-la-ciencia-ciudadana-en-espana-2017/",
#         "abstract": [
#             "Este informe corresponde al segundo año de actividad del Observatorio de la Ciencia Ciudadana en España; en él se recogen las actividades de investigación y promoción realizadas en España durante el año 2017. El informe busca aumentar nuestro conocimiento y visión sobre este conjunto de metodologías científicas, intentando entender mejor y dar a conocer los impactos de la ciencia ciudadana en la cultura científica española."
#         ],
#         "keywords": []
#     },
#     {
#         "name": "GREEN PAPER ON CITIZEN SCIENCE",
#         "url": "https://ciencia-ciudadana.es/green-paper-on-citizen-science/",
#         "abstract": [],
#         "keywords": []
#     },
#     {
#         "name": "WHITE PAPER ON CITIZEN SCIENCE FOR EUROPE / LIBRO BLANCO DE LA CIENCIA CIUDADANA",
#         "url": "https://ciencia-ciudadana.es/white-paper-on-citizen-science-for-europe/",
#         "abstract": [
#             "El Libro Blanco de la ciencia ciudadana para Europa es un documento estratégico que compila y formula las principales recomendaciones políticas de la comunidad internacional para comprender y encauzar los diversos impactos de la ciencia ciudadana.",
#             " ",
#             "En él se plantean recomendaciones concretas para facilitar la inclusión del conjunto de la sociedad en la ciencia. Reconociendo que la definición está abierta y es dinámica, describe la ciencia ciudadana como «el compromiso del público general en actividades de investigación científica al contribuir activamente a la ciencia con su esfuerzo intelectual o dando soporte al conocimiento con sus herramientas o recursos«. "
#         ],
#         "keywords": [
#             "el compromiso del público general en actividades de investigación científica al contribuir activamente a la ciencia con su esfuerzo intelectual o dando soporte al conocimiento con sus herramientas o recursos",
#             "Socientize",
#             "Instituto de Investigación BIFI ",
#             "Universidad de Zaragoza ",
#             "F",
#             "undación Ibercivis",
#             "7º Programa Marco",
#             "Infraestructuras de Investigación."
#         ]
#     },
#     {
#         "name": "INFORME DEL OBSERVATORIO DE LA CIENCIA CIUDADANA EN ESPAÑA 2016",
#         "url": "https://ciencia-ciudadana.es/informe-del-observatorio-de-la-ciencia-ciudadana-en-espana-2016/",
#         "abstract": [
#             "Este informe corresponde al segundo año de actividad del Observatorio de la Ciencia Ciudadana en España; en él se recogen las actividades de investigación y promoción realizadas en España durante el año 2016. El informe busca aumentar nuestro conocimiento y visión sobre este conjunto de metodologías científicas, intentando entender mejor y dar a conocer los impactos de la ciencia ciudadana en la cultura científica española."
#         ],
#         "keywords": []
#     }
# ]

# %%
if (EXPORT_JSON):
    with open('SpanishReports.json', 'w', encoding='utf-8') as fp:
        json.dump(lista_diccionarios_informes, fp,  ensure_ascii=False)

# %% [markdown]
# ### INFOGRAFIAS

# %%
if (SCRAP_SPANISH):

    #Set up the path to the chrome driver
    driver= webdriver.Chrome('./chromedriver.exe')
    driver.get('https://ciencia-ciudadana.es/category/infografias/')

    #Get all the names and links and store them in a list
    infografias = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')
    
    infografias_list=[]

    for infografia in infografias:
        title=infografia.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
        link = title.get_attribute('href')

        this_infografia={"Title": title.text, "Link": link}
        infografias_list.append(this_infografia)
    driver.close()

# %%
if (SCRAP_SPANISH):

    driver= webdriver.Chrome('./chromedriver.exe')

    #Create a list of dictionaries
    lista_diccionarios_infografias=[]

    #Iterate, for every element in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(infografias_list)):
        infografias_dict={}

        driver.get(infografias_list[i]["Link"])

        infografias_dict["name"]=infografias_list[i]["Title"]
        infografias_dict["url"]=infografias_list[i]["Link"]
        
        content=driver.find_element_by_xpath("//div[@class='entry-content']")

        keywords=[]
        strong=driver.find_elements_by_xpath("//strong")
        for negrita in strong:
            keywords.append(negrita.text)
        infografias_dict["keywords"]=keywords
        
        text_list=[]
        sentences = content.find_elements_by_xpath("//p")
        
        for i in range(len(sentences)-4):
            if(sentences[i].text!=""):
                text_list.append(sentences[i].text)
        infografias_dict["abstract"]=text_list

        lista_diccionarios_infografias.append(infografias_dict)
        
    driver.close()
    jprint(lista_diccionarios_infografias)
# Out:
# [
#     {
#         "name": "NUEVA PUBLICACIÓN CIENTÍFICA DEL PROYECTO COMPASS",
#         "url": "https://ciencia-ciudadana.es/nueva-publicacion-cientifica-del-proyecto-compass/",
#         "keywords": [
#             "Quantitative and qualitative evaluation of the COMPASS mobile app: a citizen science project"
#         ],
#         "abstract": [
#             "El proyecto COMPASS publicó recientemente los resultados de su actividad en un la siguiente publicación cinetífica:",
#             "Quantitative and qualitative evaluation of the COMPASS mobile app: a citizen science project",
#             "To evaluate the usability of the COMPASS application with mixed-methodol- ogy, using a citizen science approach. Parents/tutors of 10–11 years old children attending a primary school in Barcelona, Spain, were invited to take part in the study. We conducted semi-structured interviews on a subset (n = 7) of participants, two weeks after using the app for the first time. A list of suggestions of improvement was extracted from the interviews. The System Usability Scale (SUS, range 0–100) was administered to all participants before and after the improvements were implemented. We provide both a quantitative analysis (t-test of change in SUS scores) and a qualitative thematic analysis of the interviews. A total of 22 participants were included in the study. The mean score before implementation of changes was 68.5 (Standard deviation, SD = 11.1), and improved to 73.1 (10.5) (p-value = 0.025). Regarding the qualitative assessment, we obtained 24 codes and grouped them into 3 categories. It uncovered problems in the installation phase and the main barriers to use: lack of time and the need for the app to evolve. The new version of COMPASS, improved by taking into account the participants’ comments and suggestions, was more usable than the initial version.",
#             "Cardiovascular diseases; mobile applications; eHealth; mixed methodology; usability"
#         ]
#     },
#     {
#         "name": "POSTER VIRTUAL PARA LA CITSCIVIRTUAL 2021: SCIENCE AS A COMMONS",
#         "url": "https://ciencia-ciudadana.es/poster-virtual-para-la-citscivirtual-2021-science-as-a-commons/",
#         "keywords": [
#             "Maite Pelacho, Hannot Rodríguez, Fernando Broncano, Renata Kubus, Francisco Sanz, Beatriz Gavete, Antonio Lafuente",
#             "Science as a Commons: Improving the Governance of Knowledge Through Citizen Science"
#         ],
#         "abstract": [
#             "Poster virtual para la conferencia CitSciVirtual 2021, organizada por The Citizen Science Association (CSA) en mayo de 2021.",
#             "Autores del poster: Maite Pelacho, Hannot Rodríguez, Fernando Broncano, Renata Kubus, Francisco Sanz, Beatriz Gavete, Antonio Lafuente."
#         ]
#     },
#     {
#         "name": "POSTER VIRTUAL PARA LA CITSCIVIRTUAL (2021): MOTIVATIONS IN CITIZEN SCIENCE AND THE CONSTITUTION OF THE COMMONS",
#         "url": "https://ciencia-ciudadana.es/poster-virtual-para-la-citscivirtual-2021-motivations-in-citizen-science-and-the-constitution-of-the-commons/",
#         "keywords": [
#             "Maite Pelacho",
#             "Santos Orejudo",
#             "Jesús Clemente"
#         ],
#         "abstract": [
#             "Poster virtual para la CitSciVirtual (2021): Motivations in Citizen Science and the Constitution of the Commons, celebrada en mayo de 2021.",
#             "Autores:"
#         ]
#     },
#     {
#         "name": "PÓSTER: DESIGNING A SPECIFIC POLICY FOR CITIZEN SCIENCE IN SPAIN",
#         "url": "https://ciencia-ciudadana.es/poster-ecsa-2020/",
#         "keywords": [
#             "Acuerdo de Colaboración entre la Fundación Española para la Ciencia y la Tecnología (FECYT)-Ministerio de Ciencia e Innovación y la Fundación Ibercivis",
#             "Congreso online para la ciencia ciudadana y participativa 2020",
#             "European Citizen Science Association (ECSA),"
#         ],
#         "abstract": [
#             "Este póster presenta las conclusiones del Acuerdo de Colaboración entre la Fundación Española para la Ciencia y la Tecnología (FECYT)-Ministerio de Ciencia e Innovación y la Fundación Ibercivis para el fortalecimiento de la ciencia ciudadana en España. El conjunto de las acciones correspondientes a este Acuerdo se llevó a cabo desde octubre de 2018 hasta marzo de 2019.",
#             "El póster fue presentado por Maite Pelacho (Fundación Ibercivis) en el Congreso online para la ciencia ciudadana y participativa 2020, organizado por la European Citizen Science Association (ECSA), del 6 al 10 de septiembre."
#         ]
#     },
#     {
#         "name": "INFOGRAFÍA: CIENCIA CIUDADANA Y OBJETIVOS DE DESARROLLO SOSTENIBLE",
#         "url": "https://ciencia-ciudadana.es/infografia-ciencia-ciudadana-y-objetivos-de-desarrollo-sostenible/",
#         "keywords": [],
#         "abstract": []
#     },
#     {
#         "name": "INFOGRAFÍA: CIENCIACIUDADANA Y SOCIEDAD",
#         "url": "https://ciencia-ciudadana.es/infografia-cienciaciudadana-y-sociedad/",
#         "keywords": [],
#         "abstract": []
#     },
#     {
#         "name": "INFOGRAFÍA: QUÉ ES CIENCIA CIUDADANA",
#         "url": "https://ciencia-ciudadana.es/infografia-que-es-ciencia-ciudadana/",
#         "keywords": [],
#         "abstract": []
#     },
#     {
#         "name": "INFOGRAFÍA: MUNDO MAKER",
#         "url": "https://ciencia-ciudadana.es/infografia-mundo-maker/",
#         "keywords": [
#             "Observatorio de la Ciencia Ciudadana en España",
#             "Fundación Española para la Ciencia y la Tecnología FECYT."
#         ],
#         "abstract": [
#             "La comunidad maker comparte muchos de los postulados de la Ciencia Ciudadana: el trabajo de base desde instituciones no oficiales, realizado por expertos en sus áreas pero que no son necesariamente científicos de la academia, su espíritu abierto y colaborativo… Son valores que la Ciencia Ciudadana siente como propios.",
#             "El movimiento maker tiene un claro fin social, ya que los dispositivos desarrollados en su seno tienen una utilidadad clara e inmediata para sus creadores, resuelven sus inquietudes y se difunden rápidamente para dar solución a problemas de los ciudadanos."
#         ]
#     },
#     {
#         "name": "INFOGRAFÍA: ASTRONOMÍA Y CIENCIA CIUDADANA",
#         "url": "https://ciencia-ciudadana.es/infografia-astronomia-y-ciencia-ciudadana/",
#         "keywords": [
#             "La astronomía es una de las disciplinas científicas que recurre en más ocasiones a la ciencia ciudadana para avanzar en sus descubrimientos.",
#             "la gran cantidad de datos generados",
#             "el acceso a instrumentos de observación más potentes a precios competitivos",
#             "en asociaciones astronómicas",
#             "Observatorio de la Ciencia Ciudadana en España",
#             "Fundación Española para la Ciencia y la Tecnología FECYT."
#         ],
#         "abstract": [
#             "La astronomía es una de las disciplinas científicas que recurre en más ocasiones a la ciencia ciudadana para avanzar en sus descubrimientos.",
#             "Por un lado, la gran cantidad de datos generados por los actuales sistemas de observación hacen imposible su clasificación por los astrónomos, así que distribuyen estos datos entre ciudadanos de todo el mundo que contribuirán con ellos a la localización de planetas, asteroides, galaxias…. Por otro lado, el acceso a instrumentos de observación más potentes a precios competitivos incentiva la afición de millones de personas alrededor del mundo por mirar al cielo y buscar nuevos cuerpos celestes.",
#             "La astronomía realizada por ciudadanos ha sido una constante en los últimos 4 siglos, y algunos de sus descubrimientos más importantes fueron realizados por aficionados.",
#             "Estos científicos aficionados se han agrupado a lo largo de la historia en asociaciones astronómicas que reúnen e impulsan a la ciencia a través de su labor investigadora y divulgadora."
#         ]
#     }
# ]

# %%
if (EXPORT_JSON):
    with open('SpanishInfographics.json', 'w', encoding='utf-8') as fp:
        json.dump(lista_diccionarios_infografias, fp,  ensure_ascii=False)

# %% [markdown]
# ### GUÍAS Y METODOLOGÍAS

# %%
if (SCRAP_SPANISH):

    #Set up the path to the chrome driver
    driver= webdriver.Chrome('./chromedriver.exe')
    driver.get('https://ciencia-ciudadana.es/category/guias-y-metodologias/')

    #Get all the elements' names and links and store them in a list
    guias = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')
    
    guias_list=[]

    for guia in guias:
        title=guia.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
        link = title.get_attribute('href')

        this_guia={"Title": title.text, "Link": link}
        guias_list.append(this_guia)
        
    #Since there is more than one page
    num_pages = driver.find_elements_by_xpath('//a[@class="wpv-archive-pagination-link js-wpv-archive-pagination-link page-link"]')
   
    links_pages=[]
    for page in num_pages:
        links_pages.append(page.get_attribute("href"))
        
    driver.close()

# %%
if (SCRAP_SPANISH):
    driver= webdriver.Chrome('./chromedriver.exe')
    for i in range(len(links_pages)):
        driver.get(links_pages[i])
        
        #Get all the elements' names and links and store them in a list
        guias = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')

        for guia in guias:
            title=guia.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
            link = title.get_attribute('href')

            this_guia={"Title": title.text, "Link": link}
            guias_list.append(this_guia)
            
    driver.close()
    guias_list

# %%
if (SCRAP_SPANISH):

    driver= webdriver.Chrome('./chromedriver.exe')

    #Create a list of dictionaries
    lista_diccionarios_guias=[]

    #Iterate, for every element in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(guias_list)):#len(educational_resources_list)
        guias_dict={}

        
        driver.get(guias_list[i]["Link"])

        guias_dict["name"]=guias_list[i]["Title"]
        guias_dict["url"]=guias_list[i]["Link"]
        
        content=driver.find_element_by_xpath("//div[@class='entry-content']")

        keywords=[]
        strong=driver.find_elements_by_xpath("//strong")
        for negrita in strong:
            keywords.append(negrita.text)
        guias_dict["keywords"]=keywords

        text_list=[]
        sentences = content.find_elements_by_xpath("//p")

        for i in range(len(sentences)-4):
            if(sentences[i].text!=""):
                text_list.append(sentences[i].text)
        guias_dict["abstract"]=text_list

        lista_diccionarios_guias.append(guias_dict)
        
    driver.close()
    
    jprint(lista_diccionarios_guias)
# Out:
# [
#     {
#         "name": "GUÍA DIDÁCTICA DE PÁJAROS EN LA NUBE – DISEÑO Y FABRICACIÓN",
#         "url": "https://ciencia-ciudadana.es/guia-didactica-de-pajaros-en-la-nube-diseno-y-fabricacion/",
#         "keywords": [
#             "Pájaros en la Nube",
#             "ESDA – Escuela Superior de Diseño de Aragón",
#             "A través de este documento podéis conocer el proceso de diseño de la caseta y proponer actividades en el aula relacionadas con el prototipado y diseño industrial.",
#             "Pájaros en la Nube",
#             "Fundación Ibercivis",
#             "I3A – Instituto de Inavestigación en Ingeniría de Aragón",
#             "FECYT – Fundación Española para la Ciencia y la Tecnología",
#             "Fablabs de Madrid (medialab Prado), Barcelona, Sant Cugat del Vallés, Valencia, Sevilla y Zaragoza (Laboratorios CESAR en Etopia), junto a las comunidades TTN de Madrid, Barcelona, Valencia, Sevilla y Zaragoza."
#         ],
#         "abstract": [
#             "Pájaros en la Nube es un proyecto de ciencia ciudadana en el aula, que cuenta en su edición de 2020 con 85 centros de toda España que monitorizarán con estas casetas la fauna insectívora de su entorno, enviando sus datos a la nube a través del internet de las cosas.",
#             "Esta guía didáctica de fabricación, realizada junto a la ESDA – Escuela Superior de Diseño de Aragón, es un documento con el que que trabajar en el aula en la introducción al proceso de diseño y prototipado industrial.",
#             "A través de este documento podéis conocer el proceso de diseño de la caseta y proponer actividades en el aula relacionadas con el prototipado y diseño industrial.",
#             "La guía está publicada bajo licencia creative commons 4.0 y puede ser descargada, utilizada y/o modificada siempre y cuando se haga referencia a sus autores.",
#             "Pájaros en la Nube es un proyecto de la Fundación Ibercivis y el I3A – Instituto de Inavestigación en Ingeniría de Aragón, y cuenta con el apoyo de la FECYT – Fundación Española para la Ciencia y la Tecnología – Ministerio de Ciencia e Innovación. Además, el proyecto cuenta con la colaboración de los Fablabs de Madrid (medialab Prado), Barcelona, Sant Cugat del Vallés, Valencia, Sevilla y Zaragoza (Laboratorios CESAR en Etopia), junto a las comunidades TTN de Madrid, Barcelona, Valencia, Sevilla y Zaragoza."
#         ]
#     },
#     {
#         "name": "UNIDAD DIDÁCTICA ODOURCOLLECT 2021",
#         "url": "https://ciencia-ciudadana.es/unidad-didactica-odourcollect-2021/",
#         "keywords": [
#             "OdourCollect",
#             "ciencia ciudadana",
#             "investigación científica",
#             "participación",
#             "educación"
#         ],
#         "abstract": [
#             "OdourCollect es un proyecto de ciencia ciudadana sobre contaminación odorífera que convierte a estudiantes – y a sus familias, vecindario y ¡quienes quieran unirse! – en investigadores/as ambientales que exploran su ciudad para monitorizar los olores de su entorno.",
#             "A través de esta guía didáctica los estudiantes podrán descubrir cómo recolectar y categorizar olores a través del mejor de los sensores: tu nariz. Al mismo tiempo, estarán participando en un proyecto de investigación científica real.",
#             "Los tres ingredientes principales de la ciencia ciudadana son la investigación científica, la participación y la educación. Además de facilitar la adquisición de nuevos conocimientos y habilidades científicas, la ciencia ciudadana fomenta un cambio de actitud hacia la ciencia, ya que demuestra que todos/as podemos participar de diversos modos en la generación de conocimiento científico y contribuir en la resolución de problemas comunes. ¿Cómo? Proporcionando datos, analizándolos, favoreciendo nuevas herramientas para los/as investigadores/as, planteando nuevas preguntas y co-creando una nueva cultura científica."
#         ]
#     },
#     {
#         "name": "[GUÍA] CIENCIA CIUDADANA, NATURALEZA URBANA Y EDUCACIÓN AMBIENTAL",
#         "url": "https://ciencia-ciudadana.es/ciencia-ciudadana-naturaleza-urbana-y-educacion-ambiental/",
#         "keywords": [],
#         "abstract": [
#             "La guía incluye una recopilación de experiencias de Ciencia Ciudadana centradas en el ámbito de la biodiversidad urbana. Pretende analizar el potencial educativo y transformador que la Ciencia Ciudadana tiene en las personas y comunidades participantes e identificar sus aspectos más relevantes. Asimismo, quiere servir de inspiración para cualquier persona, entidad o administración pública interesada en apoyar proyectos de Ciencia Ciudadana ya existentes o crear otros nuevos, para fomentar la implicación de la sociedad en la ciencia y la conservación de la biodiversidad."
#         ]
#     },
#     {
#         "name": "OPEN SCIENCE, OPEN ISSUES",
#         "url": "https://ciencia-ciudadana.es/open-science-open-issues/",
#         "keywords": [
#             "Editores:",
#             "Año:",
#             "Editorial:",
#             "aquí"
#         ],
#         "abstract": [
#             "Este libro ofrece las contribuciones de investigadores de diferentes áreas de estudio y países, con un significativo papel en la ciencia abierta y colaborativa.",
#             "Las cuestiones en torno a la ciencia abierta están ganando terreno no sólo en los entornos institucionales de la ciencia, la tecnología y la innovación, sino también en otros contextos que, hasta ahora, se mantenían separados. Como resultado, se están movilizando otros grupos sociales como interlocutores de las prácticas científicas. ",
#             "Esta publicación busca ofrecer una visión general de temas y cuestiones que trazan e impregnan la ciencia actual desde diferentes perspectivas y puntos de vista. Por encima de todo, los editores y autores buscan una mayor reflexión para fomentar nuevas formas de producción y circulación del conocimiento. ",
#             "El libro está orientado no sólo al mundo académico, sino también a todos los actores sociales que se preocupan por la democratización del conocimiento y la información.",
#             "El libro es el resultado de los debates realizados en el Seminario Internacional “Ciência Aberta, Questões Abertas”1, realizado en 2014 en Rio de Janeiro, por el Instituto Brasileiro de Informação em Ciência e Tecnologia (IBICT), la Open Knowledge Brasil (OKBr), la Universidade Federal do Estado do Rio de Janeiro (Unirio) y el Laboratório Interdisciplinar sobre Informação e Conhecimento (Liinc).",
#             "Editores: Sarita Albagli, Maria Lucia Maciel & Alexandre Hannud Abdo",
#             "Año: 2015",
#             "Editorial: IBICT UNIRIO"
#         ]
#     },
#     {
#         "name": "PARTICIPACIÓN PÚBLICA EN LOS PROYECTOS DE INVESTIGACIÓN: FORMAS DE CREAR CONOCIMIENTO COLECTIVO EN SALUD",
#         "url": "https://ciencia-ciudadana.es/participacion-publica-conocimiento-colectivo-en-salud/",
#         "keywords": [
#             "Resumen",
#             "Autoras:",
#             "Fotografía:"
#         ],
#         "abstract": [
#             "Resumen",
#             "La participación pública en los proyectos de investigación es un ámbito emergente en España y en los países latinoamericanos. Existen cinco tipos de proyectos según el grado de implicación que las personas participantes tienen en los procesos: contributivos, colaborativos, cocreados, contractuales e independientes. Para promover la participación pública en los equipos de investigación del ámbito de la salud es necesario redefinir sus prácticas y sus competencias. Para ello, puede ser útil formularse preguntas en las diferentes fases de la investigación, así como desarrollar estrategias que incluyan audiencias que cuenten con menos canales de participación en pro de favorecer la equidad en salud. Esta forma de hacer ciencia permite reunir experiencia y experticia priorizando y adecuando la investigación a las necesidades de la población, lo que aumenta su capacidad transformadora y el impacto social de sus resultados.",
#             "Autoras: Constanza Jacques-Avinó, Mariona Pons-Vigués, Jasmine Elsie Mcghie, Israel Rodríguez-Giralt, Laura Medina-Perucha, Vinita Mahtani-Chugani, Enriqueta Pujol-Ribera, Anna Berenguera Ossó",
#             "Gaceta Sanitaria Volume 34, Issue 2, March–April 2020, Pages 200-203  https://doi.org/10.1016/j.gaceta.2019.08.010",
#             "© 2019 SESPAS. Publicado por Elsevier España, S.L.U. Este es un artículo Open Access bajo la licencia CC BY-NC-ND (http://creativecommons.org/licenses/by-nc-nd/4.0/).",
#             "El enlace para descargar el artículo – nota metodológica – desde Science Direct está aquí.",
#             "Fotografía: Constanza Jacques Aviñó del IDIAPJGol."
#         ]
#     },
#     {
#         "name": "PLAN NACIONAL DE ADAPTACIÓN AL CAMBIO CLIMÁTICO 2021-2030",
#         "url": "https://ciencia-ciudadana.es/plan-nacional-de-adaptacion-al-cambio-climatico-2021-2030/",
#         "keywords": [
#             "una herramienta fundamental hacia la reconstrucción verde de España cuyo principal objetivo es construir un país menos vulnerable, más seguro y resiliente a los impactos y riesgos del cambio climático, capaz de anticipar, de responder y de adaptarse a un contexto de clima cambiante.",
#             "aquí."
#         ],
#         "abstract": [
#             "El Consejo de Ministros, a propuesta del Ministerio para la Transición Ecológica y el Reto Demográfico, aprobó, el 22 de septiembre de 2020, el segundo Plan Nacional de Adaptación al Cambio Climático (PNACC) 2021-2030, una herramienta fundamental hacia la reconstrucción verde de España cuyo principal objetivo es construir un país menos vulnerable, más seguro y resiliente a los impactos y riesgos del cambio climático, capaz de anticipar, de responder y de adaptarse a un contexto de clima cambiante.",
#             "Enlace para descargar PDF aquí."
#         ]
#     },
#     {
#         "name": "GUÍA DE LAS ESPECIES EXÓTICAS E INVASORAS DE LOS RÍOS, LAGOS Y ESTUARIOS DE LA PENÍNSULA IBÉRICA",
#         "url": "https://ciencia-ciudadana.es/guia-especies-exoticas-e-invasoras/",
#         "keywords": [
#             "LIFE INVASAQUA",
#             "Programa LIFE de la Comisión Europea",
#             "Edición y coordinación de la obra:",
#             "Revisión científica:",
#             "Diseño iconografías y portada:",
#             "Edita:"
#         ],
#         "abstract": [
#             "Esta Guía ha sido realizada en el marco del proyecto LIFE INVASAQUA (LIFE17 GIE/ES/000515) Aquatic Invasive Alien Species of Freshwater and Estuarine Systems: Awareness and Prevention in the Iberian Peninsula, financiado por el Programa LIFE de la Comisión Europea.",
#             "Edición y coordinación de la obra: Frederic Casals y Jorge Rubén Sánchez-González\nRevisión científica: Filipe Ribeiro, Pedro M. Anastácio, Miguel Morgado-Santos",
#             "Diseño iconografías y portada: Alfonso Nombela Gómez (MNCN-CSIC)",
#             "Edita: Sociedad Ibérica de Ictiología",
#             "Descargar PDF aquí."
#         ]
#     },
#     {
#         "name": "MANAGING INTELLECTUAL PROPERTY RIGHTS IN CITIZEN SCIENCE: A GUIDE FOR RESEARCHERS AND CITIZEN SCIENTISTS",
#         "url": "https://ciencia-ciudadana.es/guide_ip_rights_citizen_science/",
#         "keywords": [
#             "cuestiones de propiedad intelectual",
#             "perspectivas de los investigadores, los participantes y el público en general",
#             "Autoras:",
#             "Edición:",
#             "Año:",
#             "aquí."
#         ],
#         "abstract": [
#             "Este estudio identifica y explica las cuestiones de propiedad intelectual que surgen en los proyectos de ciencia ciudadana, teniendo en cuenta las perspectivas de los investigadores, los participantes y el público en general.",
#             "Autoras: Teresa Scassa y Haewon.",
#             "Edición: Washington, DC: Woodrow Wilson International Center for Scholars.",
#             "Año: 2015"
#         ]
#     },
#     {
#         "name": "TENDENCIAS RECIENTES EN LAS POLÍTICAS CIENTÍFICAS DE CIENCIA ABIERTA Y ACCESO ABIERTO EN IBEROAMÉRICA",
#         "url": "https://ciencia-ciudadana.es/ciencia_abierta_clacso_fcarolina/",
#         "keywords": [
#             "reconstruir y analizar el estado de las investigaciones y las políticas científicas en acceso abierto, datos abiertos de investigación y ciencia abierta en Iberoamérica",
#             "evaluación de trayectorias investigativas, publicaciones científicas e indicadores de impacto",
#             "CLACSO y la Fundación Carolina",
#             "aquí."
#         ],
#         "abstract": [
#             "El propósito general del informe busca reconstruir y analizar el estado de las investigaciones y las políticas científicas en acceso abierto, datos abiertos de investigación y ciencia abierta en Iberoamérica e indagar su incidencia en la evaluación de trayectorias investigativas, publicaciones científicas e indicadores de impacto. Con ello, CLACSO y la Fundación Carolina persiguen contribuir desde el desarrollo de conocimientos locales y situados al tratamiento y posible resolución de los grandes desafíos planteados por los Objetivos de Desarrollo Sostenible de la Agenda 2030.",
#             "Autoras: Dominique Babini & Laura Rovelli",
#             "El PDF del documento puede descargarse aquí.",
#             " "
#         ]
#     },
#     {
#         "name": "MINI-GUÍAS ARANZADI DE NATURALEZA",
#         "url": "https://ciencia-ciudadana.es/mini-guias-aranzadi-de-naturaleza/",
#         "keywords": [],
#         "abstract": []
#     },
#     {
#         "name": "CHOOSING AND USING CITIZEN SCIENCE",
#         "url": "https://ciencia-ciudadana.es/choosing-and-using-citizen-science/",
#         "keywords": [
#             "Pocock, M.J.O., Chapman, D.S.,Sheppard, L.J. & Roy, H.E. (2014).",
#             "Centre for Ecology & Hydrology"
#         ],
#         "abstract": [
#             "Autores: Pocock, M.J.O., Chapman, D.S.,Sheppard, L.J. & Roy, H.E. (2014).Choosing and Using Citizen Science: a guide to when and how to use citizen science to monitor biodiversity and the environment. Centre for Ecology & Hydrology."
#         ]
#     },
#     {
#         "name": "LA GESTIÓN ÉTICA DE LOS DATOS",
#         "url": "https://ciencia-ciudadana.es/la-gestion-etica-de-los-datos/",
#         "keywords": [],
#         "abstract": [
#             "Cada vez más, actores públicos y privados se plantean cómo escalar su impacto a través del uso de la tecnología. Al mismo tiempo, el uso y gestión de los datos personales de millones de personas preocupa a los ciudadanos y existe un sentimiento de urgencia sobre la necesidad de proteger la seguridad y privacidad de los datos usados. ¿Qué medidas se pueden tomar y cuál es el riesgo de no tomarlas? ¿Cómo puede el sector público gestionar los datos de forma responsable? Este documento ofrece marcos de referencia sobre la gestión ética de datos y sobre la importancia del consentimiento, un compendio de mejores prácticas y una hoja de ruta con pasos concretos para una gestión responsable de datos por parte del sector público.",
#             "DOI: http://dx.doi.org/10.18235/0001623",
#             "Autores: Buenadicha Sánchez, César; Galdon Clavell, Gemma; Hermosilla, María; Loewe, Daniel; Pombo, Cristina"
#         ]
#     },
#     {
#         "name": "UNIDAD DIDÁCTICA DE CITIES AT NIGHT",
#         "url": "https://ciencia-ciudadana.es/unidad-didactica-de-cities-at-night/",
#         "keywords": [
#             "Cities at Night",
#             "trabajar en el aula con alumnos de tercero y cuarto de secundaria",
#             "Cities at Nigh",
#             "contenidos generales sobre la contaminación lumínica, sus tipos y los efectos negativos de la iluminación artificial nocturna",
#             "el proyecto Cities at Night",
#             "contenidos que se pueden implementar en el aula",
#             "Los proyectos de ciencia ciudadana",
#             "El material está publicado bajo licencia Creative Commons CC BY-SA 4.0 ES, de acceso libre y gratuito, pudiendo ser compartido, copiado y modificado, respetando siempre su autoría."
#         ],
#         "abstract": [
#             "Como parte del desarrollo del proyecto de ciencia ciudadana Cities at Night, el equipo del proyecto ha elaborado una unidad didáctica destinada a complementar en el aula los conocimientos obtenidos por los alumnos de educación secundaria que se han unido y participado en el proyecto.",
#             "La Unidad Didáctica es una propuesta para trabajar en el aula con alumnos de tercero y cuarto de secundaria, la localización de fuentes de la contaminación lumínica a través del proyecto de ciencia ciudadana Cities at Night.",
#             "Presenta contenidos generales sobre la contaminación lumínica, sus tipos y los efectos negativos de la iluminación artificial nocturna, para explicar después el modo más eficiente de instalar fuentes de iluminación que minimicen estos efectos. ",
#             "Posteriormente se presenta el proyecto Cities at Night, sus objetivos y su relación con la ciencia ciudadana, junto a unas actividades sugeridas que se adaptan al nivel del alumnado. Por último, se indican algunos enlaces para ampliar información, tanto para los docentes como para los estudiantes. ",
#             "Pretendemos presentar unos contenidos que se pueden implementar en el aula, y una guía para que tanto el alumnado como los docentes puedan participar en este proyecto de ciencia ciudadana.",
#             "Los proyectos de ciencia ciudadana se construyen con la aportación de muchas personas. Investigadores, divulgadores y voluntarios de todo tipo contribuyen con sus aportaciones para que el proyecto crezca generando una utilidad para la ciencia y la sociedad."
#         ]
#     },
#     {
#         "name": "GUÍA DIDÁCTICA VIGILANTES DEL AIRE",
#         "url": "https://ciencia-ciudadana.es/guia-didactica-vigilantes-del-aire/",
#         "keywords": [
#             "La Unidad didáctica del proyecto Vigilantes del Aire es un material educativo",
#             "para ser utilizado en el aula o en familia",
#             "guía es gratuita y abierta"
#         ],
#         "abstract": [
#             "La Unidad didáctica del proyecto Vigilantes del Aire es un material educativo apto para cualquier nivel de formación -infantil, primaria y secundaria-, para ser utilizado en el aula o en familia y así poder conocer mejor la contaminación del aire que se estudia gracias a los participantes en #VigilantesDelAire.",
#             "La guía es gratuita y abierta, y se puede utilizar en el aula o en familia, total o parcialemente, o modificarla o ampliarla siemrpe que se cite a sus autores correctamente."
#         ]
#     },
#     {
#         "name": "GUÍA: CIÈNCIA CIUTADANA I APRENENTATGE SERVEI (DISPONIBLE EN CATALÁN Y CASTELLANO)",
#         "url": "https://ciencia-ciudadana.es/guia-ciencia-ciutadana-i-aprenentatge-servei/",
#         "keywords": [
#             "Centro Promotor de Aprendizaje Servicio y de la Oficina de Ciencia Ciudadana de Barcelona",
#             "Esta guía está disponible para su descarga y consulta en los enlaces que presentamos a continuación",
#             "Oficina de la Ciencia Ciudadana de Barcelona",
#             "Asociación Centro Promotor de Aprendizaje Servicio",
#             "Fundación Ibercivis"
#         ],
#         "abstract": [
#             "Este informe es el resultado de una iniciativa conjunta del Centro Promotor de Aprendizaje Servicio y de la Oficina de Ciencia Ciudadana de Barcelona que pretende aunar ciencia ciudadana y el aprendizaje servicio para señalar las semejanzas y explorar posibilidades de colaboración.",
#             "Barcelona cuenta con un alto capital de conocimiento gracias a una gran actividad científica y tecnológica. En los últimos años, además, varios grupos de investigación han incorporado la ciencia ciudadana en sus proyectos abriendo, así, la investigación a la participación. En este contexto nace, en 2012, la Oficina de Ciencia Ciudadana de Barcelona, impulsada por el Instituto de Cultura de Barcelona. Con una veintena de projectesde investigación, desde la oficinas donasuport a la ciencia ciudadana que se hace en Barcelona y el área metropolitana a través de acciones y programas transversales, se asesora y se impulsa proyectos jóvenes y de nueva creación, y se trabaja para las buenas prácticas en torno a la investigación participada.",
#             "Esta guía está disponible para su descarga y consulta en los enlaces que presentamos a continuación, en sus versiones en catalán y en castellano. Además, está disponible en las páginas web de la Oficina de la Ciencia Ciudadana de Barcelona, la Asociación Centro Promotor de Aprendizaje Servicio y la Fundación Ibercivis."
#         ]
#     },
#     {
#         "name": "CIÉNCIA CIUTADANA A LES BIBLIOTEQUES",
#         "url": "https://ciencia-ciudadana.es/articulo-ciencia-ciutadana-a-les-biblioteques/",
#         "keywords": [
#             "El Laboratorio de Ciencia Ciudadana",
#             "reflexiones colectivas sobre las razones para introducir la Ciencia Ciudadana en las bibliotecas y los beneficios que puede aportar en este contexto a las personas, a las comunidades ya los propios equipamientos culturales",
#             "las bibliotecas han seleccionado diez proyectos de ciencia ciudadana que están actualmente en funcionamiento y han imaginado cómo sería su implantación en su municipio, adaptándose a las particularidades culturales y socio de su espacio, barrio y población"
#         ],
#         "abstract": [
#             "Autores: Perelló, Josep; Bonhoure, Isabelle; Cigarini, Anna; Vicens, Julià.",
#             "El Laboratorio de Ciencia Ciudadana, dirigido a los profesionales de las bibliotecas públicas, quiso descubrir e investigar de forma participativa el potencial de las bibliotecas públicas como espacios donde generar nuevo conocimiento con y para la ciudadanía. Desde el mes de noviembre de 2018 hasta junio de 2019, veintidós cinco bibliotecas han participado en cinco sesiones teórico-prácticas que ofrecen una visión actualizada de la ciencia ciudadana en todo el mundo y han planteado el debate sobre cómo puede implicarse una biblioteca municipal. La publicación recoge estas reflexiones colectivas sobre las razones para introducir la Ciencia Ciudadana en las bibliotecas y los beneficios que puede aportar en este contexto a las personas, a las comunidades ya los propios equipamientos culturales. La formación ha servido también para capacitar a los y las profesionales participantes como mediadores entre ciudadanía y ciencia."
#         ]
#     },
#     {
#         "name": "GUÍA: CÓMO HACER UNA MINIETNOGRAFÍA. LA AVENTURA DE APRENDER.",
#         "url": "https://ciencia-ciudadana.es/como-hacer-una-minietnografia/",
#         "keywords": [
#             "el conocimiento es una empresa colaborativa, colectiva, social y abierta",
#             "hay mucho conocimiento que no surge intramuros de la academia o de cualquiera de las instituciones canónicas especializadas",
#             "el conocimiento es una actividad más de hacer que de pensar y menos argumentativa que experimental"
#         ],
#         "abstract": [
#             "Una nueva guía dentro del proyecto La aventura de aprender bajo la coordinación de Antonio Lafuente.",
#             "La Aventura de Aprender es un espacio de encuentro e intercambio en torno a los aprendizajes para descubrir qué prácticas, atmósferas, espacios y agentes hacen funcionar las comunidades; sus porqués y sus cómos o en otras palabras, sus anhelos y protocolos."
#         ]
#     },
#     {
#         "name": "CIENCIA CIUDADANA: PRINCIPIOS, HERRAMIENTAS, PROYECTOS DE MEDIO AMBIENTE",
#         "url": "https://ciencia-ciudadana.es/ciencia-ciudadana-principios-herramientas-proyectos-de-medio-ambiente/",
#         "keywords": [
#             "Fundación Ciencia Ciudadana",
#             "Embajada de Canadá"
#         ],
#         "abstract": [
#             "«¿Alguna vez quisiste diseñar un proyecto y no supiste cómo empezar? ¿O empezaste a escribir tu idea y no se te ocurrió como seguir? A nosotros nos pasó muchas veces, y a lo largo de nuestra trayectoria como Fundación recibimos constantemente preguntas vinculadas a métodos para realizar proyectos, en su mayoría relacionados con estudios ambientales. Con esta publicación queremos responder esas preguntas, ofreciendo herramientas útiles asociadas a una metodología para el diseño de proyectos de Ciencia Ciudadana.",
#             "Puedes empezar esta guía donde quieras. Si bien hay una estructura paso a paso, el diseño de cada herramienta ha sido hecho para que tomes lo que necesites, compares y modifiques el contenido según tus propias necesidades. (…)",
#             "Esperamos que esta publicación anime a más personas a diseñar y ser parte de investigaciones que fomenten la participación ciudadana. Nuestra misión es transformar la cultura científica del país por medio de la colaboración y la inclusión, y esperamos que este sea un pequeño aporte para ello.»"
#         ]
#     },
#     {
#         "name": "INNOVATION IN OPEN SCIENCE, SOCIETY AND POLICY",
#         "url": "https://ciencia-ciudadana.es/innovation-in-open-science-society-and-policy/",
#         "keywords": [
#             "Susanne Hecker",
#             "Muki Haklay",
#             "Anne Bowser",
#             "Zen Makuch",
#             "Johannes Vogel",
#             "Aletta Bon"
#         ],
#         "abstract": [
#             "«Citizen science, the active participation of the public in scientific research projects, is a rapidly expanding field in open science and open innovation. It provides an integrated model of public knowledge production and engagement with science. As a growing worldwide phenomenon, it is invigorated by evolving new technologies that connect people easily and effectively with the scientific community. Catalyzed by citizens’ wishes to be actively involved in scientific processes, as a result of recent societal trends, it also offers contributions to the rise in tertiary education. In addition, citizen science provides a valuable tool for citizens to play a more active role in sustainable development.",
#             "This book identifies and explains the role of citizen science within innovation in science and society, and as a vibrant and productive science-policy interface. The scope of this volume is global, geared towards identifying solutions and lessons to be applied across science, practice and policy. The chapters consider the role of citizen science in the context of the wider agenda of open science and open innovation and discuss progress towards responsible research and innovation, two of the most critical aspects of science today.«"
#         ]
#     },
#     {
#         "name": "GUÍA PARA CONOCER LA CIENCIA CIUDADANA",
#         "url": "https://ciencia-ciudadana.es/guia-para-conocer-la-ciencia-ciudadana/",
#         "keywords": [
#             "Este material tiene como objetivo ser un instrumento básico e introductorio",
#             "dirigida",
#             "a quienes están pensando incorporar la participación ciudadana en sus proyectos de investigación",
#             "un valor para el desarrollo de la ciencia y la sociedad."
#         ],
#         "abstract": [
#             "«La Ciencia Ciudadana es una temática que se aborda prácticamente en el mundo entero, pero que todavía dispone de poca información en español, barrera que impide el acceso a más personas para que conozcan este enfoque y se entusiasmen con la idea de la ciencia colaborativa. Este material tiene como objetivo ser un instrumento básico e introductorio para conocer más respecto a esta Ciencia Ciudadana resolviendo dudas sobre sus diferentes enfoques y métodos."
#         ]
#     }
# ]

# %%
if (EXPORT_JSON):
    with open('SpanishGuides.json', 'w', encoding='utf-8') as fp:
        json.dump(lista_diccionarios_guias, fp,  ensure_ascii=False)

# %% [markdown]
# ### MÉTRICAS E INDICADORES

# %%
if (SCRAP_SPANISH):

    #Set up the path to the chrome driver
    driver= webdriver.Chrome('./chromedriver.exe')
    driver.get('https://ciencia-ciudadana.es/category/metricas-e-indicadores/')

    #Get all the elements' names and links and store them in a list
    metricas = driver.find_elements_by_xpath('//div[@class="tb-grid-column"]')
    
    metricas_list=[]

    for metrica in metricas:
        title=metrica.find_element_by_xpath('.//h4[@class="tb-heading has-text-color"]/a')#.text
        link = title.get_attribute('href')

        this_metrica={"Title": title.text, "Link": link}
        metricas_list.append(this_metrica)
        
    driver.close()

# %%
if (SCRAP_SPANISH):

    driver= webdriver.Chrome('./chromedriver.exe')

    #Create a list of dictionaries
    lista_diccionarios_metricas=[]

    #Iterate, for every element in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(metricas_list)):#len(educational_resources_list)
        metricas_dict={}

        driver.get(metricas_list[i]["Link"])

        metricas_dict["name"]=metricas_list[i]["Title"]
        metricas_dict["url"]=metricas_list[i]["Link"]
        
        content=driver.find_element_by_xpath("//div[@class='entry-content']")

        keywords=[]
        strong=driver.find_elements_by_xpath("//strong")
        for negrita in strong:
            keywords.append(negrita.text) 
        metricas_dict["keywords"]=keywords

        text_list=[]
        sentences = content.find_elements_by_xpath("//p")

        for i in range(len(sentences)-4):
            if(sentences[i].text!=""):
                text_list.append(sentences[i].text)
        metricas_dict["abstract"]=text_list

        lista_diccionarios_metricas.append(metricas_dict)
        
    driver.close()
    jprint(lista_diccionarios_metricas)
# Out:
# [
#     {
#         "name": "PLAN NACIONAL DE ADAPTACIÓN AL CAMBIO CLIMÁTICO 2021-2030",
#         "url": "https://ciencia-ciudadana.es/plan-nacional-de-adaptacion-al-cambio-climatico-2021-2030/",
#         "keywords": [
#             "una herramienta fundamental hacia la reconstrucción verde de España cuyo principal objetivo es construir un país menos vulnerable, más seguro y resiliente a los impactos y riesgos del cambio climático, capaz de anticipar, de responder y de adaptarse a un contexto de clima cambiante.",
#             "aquí."
#         ],
#         "abstract": [
#             "El Consejo de Ministros, a propuesta del Ministerio para la Transición Ecológica y el Reto Demográfico, aprobó, el 22 de septiembre de 2020, el segundo Plan Nacional de Adaptación al Cambio Climático (PNACC) 2021-2030, una herramienta fundamental hacia la reconstrucción verde de España cuyo principal objetivo es construir un país menos vulnerable, más seguro y resiliente a los impactos y riesgos del cambio climático, capaz de anticipar, de responder y de adaptarse a un contexto de clima cambiante.",
#             "Enlace para descargar PDF aquí."
#         ]
#     },
#     {
#         "name": "TENDENCIAS RECIENTES EN LAS POLÍTICAS CIENTÍFICAS DE CIENCIA ABIERTA Y ACCESO ABIERTO EN IBEROAMÉRICA",
#         "url": "https://ciencia-ciudadana.es/ciencia_abierta_clacso_fcarolina/",
#         "keywords": [
#             "reconstruir y analizar el estado de las investigaciones y las políticas científicas en acceso abierto, datos abiertos de investigación y ciencia abierta en Iberoamérica",
#             "evaluación de trayectorias investigativas, publicaciones científicas e indicadores de impacto",
#             "CLACSO y la Fundación Carolina",
#             "aquí."
#         ],
#         "abstract": [
#             "El propósito general del informe busca reconstruir y analizar el estado de las investigaciones y las políticas científicas en acceso abierto, datos abiertos de investigación y ciencia abierta en Iberoamérica e indagar su incidencia en la evaluación de trayectorias investigativas, publicaciones científicas e indicadores de impacto. Con ello, CLACSO y la Fundación Carolina persiguen contribuir desde el desarrollo de conocimientos locales y situados al tratamiento y posible resolución de los grandes desafíos planteados por los Objetivos de Desarrollo Sostenible de la Agenda 2030.",
#             "Autoras: Dominique Babini & Laura Rovelli",
#             "El PDF del documento puede descargarse aquí.",
#             " "
#         ]
#     },
#     {
#         "name": "FECYT: INDICADORES DE I+D+I 2017",
#         "url": "https://ciencia-ciudadana.es/fecyt-indicadores-de-idi-2017/",
#         "keywords": [
#             "Haz click en el siguiente botón para acceder al documento en PDF:"
#         ],
#         "abstract": [
#             "«El Observatorio Español de I+D+I (ICONO) de la Fundación Española para la Ciencia y la Tecnología (FECYT) genera y analiza de forma rigurosa, la información más actual en relación a los principales indicadores y estrategias de ciencia e innovación autonómicos, nacionales e internacionales. Con el objetivo de medir la evolución de los indicadores más significativos relacionados con ciencia e innovación, ICONO publica su libro de Indicadores del Sistema Español de Ciencia, Tecnología e Innovación, edición 2017. El presente documento además de aportar indicadores objetivos sobre la evolución de la ciencia y la innovación en España, muestra la comparación con el contexto internacional y la distribución por comunidades autónomas en aquellos casos en los que se dispone de información estadística óptima. Al igual que en ediciones anteriores, los datos reflejan los recursos -económicos y humanos- de los que dispone el Sistema y los resultados de las actividades de investigación científica, desarrollo e innovación en España. (…)«",
#             " "
#         ]
#     },
#     {
#         "name": "METRICS AND INDICATORS OF RESPONSIBLE RESEARCH AND INNOVATION",
#         "url": "https://ciencia-ciudadana.es/5275-2/",
#         "keywords": [],
#         "abstract": [
#             "«This deliverable is the second of two reports within Task 3 of the MoRRI project. In short, the objective of Task 3 has been to construct, identify, and specify relevant metrics and indicators to be used in the subsequent RRI monitoring. Whereas the previous report (D.3.1) synthesised and assessed existing indicators and secondary data, this report (D.3.2) will [a] pin down the final, core set of RRI indicators, [b] provide detailed descriptions of each indicator, and [c] specify the primary and secondary data and procedures guiding the data-collection in Task 4. It should be noted that the indicators selected and presented in this report tap into RRI practices that could be used for monitoring the evolution of RRI across Europe. Later tasks of the MoRRI project will develop indicators focusing specifically on the societal benefits and impacts of such RRI practices. (…)«",
#             " "
#         ]
#     },
#     {
#         "name": "INFORME: METRICS AND INDICATORS OF RESPONSIBLE RESEARCH AND INNOVATION",
#         "url": "https://ciencia-ciudadana.es/informe-metrics-and-indicators-of-responsible-research-and-innovation/",
#         "keywords": [],
#         "abstract": []
#     },
#     {
#         "name": "MÉTRICAS DE INDICADORES DE INNOVACIÓN NO-TECNOLÓGICA (MINT)",
#         "url": "https://ciencia-ciudadana.es/metricas-de-indicadores-de-innovacion-no-tecnologica-mint/",
#         "keywords": [
#             "Más información en la web de la Fundación COTEC.",
#             "Proyecto seleccionado en el Programa de Innovación Abierta (PIA) 2016 de Cotec. Se trata de un estudio de las métricas de innovación desde una interpretación ampliada del concepto de innovación no-tecnológica",
#             "marzo 2016",
#             "marzo 2017",
#             "Luis Rubalcaba, de la Universidad de Alcalá, Jorge Gallego, de la Universidad Autónoma de Madrid, y David Gago, de la Universidad San Pablo-CEU."
#         ],
#         "abstract": [
#             "Ante el tradicional predomino de la dimensión tecnológica en el análisis del desempeño innovador de las organizaciones, el estudio revisa y reinterpreta el concepto de innovación en su dimensión no-tecnológica, ampliando la definición tradicional contemplada en el Manual de Oslo.",
#             "Además, se propone una nueva métrica de innovación no-tecnológica escalable y flexible (anexo) en la que se consideran tanto los distintos servicios que conforman la cadena de valor de cualquier organización como procesos fundamentales (ej., logística, control y calidad, marketing, etc.). También se consideran las mejoras en dichos procesos de servicio con la componente procedimental de la innovación organizativa (nuevas prácticas o métodos en la organización del trabajo o de los procedimientos de la organización) y se abordan aspectos novedosos como la innovación abierta y social, entre otros.",
#             "Más información en la web de la Fundación COTEC.",
#             "Descripción: Proyecto seleccionado en el Programa de Innovación Abierta (PIA) 2016 de Cotec. Se trata de un estudio de las métricas de innovación desde una interpretación ampliada del concepto de innovación no-tecnológica",
#             "Fecha de inicio: marzo 2016",
#             "Fecha de finalización: marzo 2017"
#         ]
#     }
# ]

# %%
if (EXPORT_JSON):
    with open('SpanishMetrics.json', 'w', encoding='utf-8') as fp:
        json.dump(lista_diccionarios_metricas, fp,  ensure_ascii=False)

# %% [markdown]
# ## Barcelona

# %%
SCRAP_BCN=True

# %%
if (SCRAP_BCN):
    #Import the google chrome driver 
    driver= webdriver.Chrome('./chromedriver.exe')
    
    bcn_projects_list=[]

    driver.get('https://www.barcelona.cat/barcelonaciencia/es/proyectos-ciencia-ciudadana')
    
    #Get all the projects titles and links and store them in a list
    titles=driver.find_elements_by_xpath('//a[@class="color-black"]')
    for title in titles:
        this_project={"Title": title.text, "Link": title.get_attribute('href')}
        bcn_projects_list.append(this_project)

# %%
if (SCRAP_BCN):

    #Create a list of dictionaries
    lista_diccionarios=[]

    #Iterate, for every project in the list: store the desired fields in a dictionary and append the 
    #dictionary to the lista_diccionarios
    for i in range(len(bcn_projects_list)):
        project_dict={}

        driver.get(bcn_projects_list[i]["Link"])
        project_dict["name"]=bcn_projects_list[i]["Title"]

        left_area=driver.find_element_by_xpath("//*[@id='block-system-main']/div[2]/div/div[1]")
        project_dict["description"]=left_area.find_element_by_xpath(".//p[2]").text

        #Since for some cases the strong expression is a little bit different (includes the white space or not..), these try and except
        #manage to get the fields for all cases, and if they are empty they are set to null. 
        try:
            try:
                text = driver.find_element_by_xpath("//p[strong = 'Estado:']").text.strip()
            except:
                text = driver.find_element_by_xpath("//p[strong = 'Estado: ']").text.strip()
            project_dict["status"] = text.split(":")[-1].strip()
        except:
            project_dict["status"]=""

        try:
            try:
                text = driver.find_element_by_xpath("//p[strong = 'Actividades en el marco de la Oficina: ']").text.strip()
            except:
                text = driver.find_element_by_xpath("//p[strong = 'Actividades en el marco de la Oficina:']").text.strip()
        except:
            text = driver.find_element_by_xpath("//p[strong = 'Actividades en el marco de la Oficina']").text.strip()
        project_dict["activities"]=  text.split(":")[-1].strip() 


        try:
            try:
                try:
                    text = driver.find_element_by_xpath("//p[strong = 'Ámbito: ']").text.strip()
                except:
                    text = driver.find_element_by_xpath("//p[strong = 'Ámbito:']").text.strip()
            except:
                    text = driver.find_element_by_xpath("//p[strong = 'mbito:']").text.strip()
            project_dict["topic"]=text.split(":")[-1].strip()
        except: project_dict["topic"]="" 

        project_dict["bcn_url"]=bcn_projects_list[i]["Link"]
        project_dict["official_url"]=driver.find_element_by_xpath("//div[@class='field-item even']/a").get_attribute('href')

        lista_diccionarios.append(project_dict)
    driver.close()

# %%
lista_diccionarios
# Out:
# [{'name': 'Beepath',
#   'description': 'Beepath es una herramienta que permite estudiar la movilidad humana, registrándola a través de una aplicación para dispositivos móviles. Se lleva a cabo con la participación directa, voluntaria y consciente de ciudadanos y ciudadanas. Mantiene una comunicación directa con los usuarios y hace accesible los resultados de la investigación. Además, ofrece en abierto códigos y los datos de los experimentos para quien desee utilizar los recursos generados.',
#   'status': 'activo periódicamente',
#   'activities': 'Programa en los Barrios, Programa en las escuelas, Fiesta de la Ciencia, Safari del ECSA 2015, Comunidad de práctica',
#   'topic': 'social',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/beepath',
#   'official_url': 'http://www.ub.edu/opensystems/ca/projectes/beepath/'},
#  {'name': 'BioBlitz Barris',
#   'description': 'BioBlitz Barris pretende utilitzar el método BioBlitz, en el que personas expertas, ciudadanos y ciudadanas trabajan codo a codo para identificar el máximo número de especies posible en una área determinada, para dar a conocer y a valorar la biodiversidad de su barrio y proporcionar herramientas para tomar el pulso de la salud de su ciudad. Se han hecho BioBlitz Barris en Sarrià-Sant Gervasi, en el Parque del Turó del Putget y en el Parque del Turó de l’Oreneta. Los datos recogidos se integran en la plataforma Natusfera, en la cual, una vez validadas, se vuelcan en la plataforma GBIF de biodiversidad global.',
#   'status': 'activo periódicamente',
#   'activities': 'Programa en los Barrios, Fiesta de la Ciencia, Comunidad de práctica',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/bioblitz-barris',
#   'official_url': 'https://bioblitzbarris.net/'},
#  {'name': 'BioBlitzBcn',
#   'description': 'Un BioBlitz es un censo exhaustivo y colaborativo de especies biológicas de un área determinada. Típicamente realizado en parques urbanos, esta iniciativa de exploración y descubrimiento de la naturaleza a contrarreloj cuenta con la ayuda de estudiantes de escuelas y personas voluntarias entre otros participantes, que cuentan con la guía a cargo de biólogos y biólogas. Desde el 2010, Barcelona organiza un BioBlitz anual en el que ya han participado más de 4.000 personas y se han identificado cerca de 3.000 especies.',
#   'status': 'activo periódicamente',
#   'activities': 'Programa los Barrios, Comunidad de práctica',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/bioblitzbcn',
#   'official_url': 'http://bioblitzbcn.museuciencies.cat/'},
#  {'name': 'Cities-Health',
#   'description': 'Cities-Health busca situar las preocupaciones de los ciudadanos y ciudadanas en el centro de la agenda en investigación. Residentes de cinco ciudades europeas, entre ellas Barcelona, diseñan y realizan experimentos para explorar cómo la contaminación de su entorno está afectando su salud. La propia ciudadanía es quien define qué investigar, de qué manera y qué acciones se deberían tomar con los resultados obtenidos.',
#   'status': 'activo',
#   'activities': 'Fiesta de la Ciencia, Comunidad de práctica',
#   'topic': 'salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/cities-health-0',
#   'official_url': 'https://www.citieshealthbcn.eu/en/sobre-el-projecte'},
#  {'name': 'Floodup',
#   'description': 'Floodup tiene como objetivo mejorar el conocimiento de las inundaciones y lluvias intensas y su impacto, así como incrementar la información de que dispone la comunidad científica. Para facilitar la participación, se han creado herramientas que permiten compartir observaciones de inundaciones recientes y históricas, lluvias y otros fenómenos, donde destacan el sitio web del proyecto y una app para dispositivos móviles. Las herramientas también per miten compartir observaciones de marcas de altura de agua históricas, lugares vulnerables a las inundaciones o medidas de adaptación a estos episodios.',
#   'status': 'activo',
#   'activities': 'Programa en las escuelas, Fiesta de la Ciencia, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/floodup',
#   'official_url': 'http://www.floodup.ub.edu/'},
#  {'name': 'Genigma',
#   'description': 'Este proyecto codiseña con la ciudadanía un juego para investigar las alteraciones genómicas en células cancerosas. El juego Genigma pretende ser una herramienta mediante la cual la ciudadanía podrá colaborar con la investigación. Con teléfonos móviles, cualquier ciudadano o ciudadana podrá analizar pequeños fragmentos del ADN de estas células y colaborar en la construcción del mapa genómico de referencia. El mapa permitirá entender qué partes del genoma de estas células juegan un papel fundamental en el establecimiento y desarrollo del cáncer y será de gran utilidad para diseñar tratamientos más personalizados y efectivos contra el cáncer.',
#   'status': 'activo',
#   'activities': 'Comunidad de práctica',
#   'topic': 'salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/genigma',
#   'official_url': 'https://genigma.app/ca/'},
#  {'name': 'InSPIRES',
#   'description': 'El proyecto InSPIRES apunta al levantamiento de demandas sociales de cara a la construcción, a medio y largo plazo, de proyectos de investigación que aborden estas necesidades para la transformación social. El proyecto colabora con la Oficina en los procesos para fomentar la participación, para valorar en qué medida alguna de las demandas sociales recogidas podrían ser encaradas a través de proyectos de formato de science shop, especialmente en los campos de la salud y del estudio del medio ambiente.',
#   'status': '',
#   'activities': 'Fiesta de la Ciencia, Comunidad de práctica',
#   'topic': 'social',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/inspires',
#   'official_url': 'http://www.inspiresproject.eu/'},
#  {'name': 'Juegos para el Cambio Social',
#   'description': 'Juegos para el Cambio Social. El proyecto recoge experimentos portátiles dirigidos a responder inquietudes compartidas por grupos de ciudadanos y ciudadanas. Utiliza dilemas sociales en forma de juegos para medir caracteres de conducta de colectivos concretos en espacios públicos y urbanos. Los resultados generados son una herramienta potente para medir el capital social en grupos y aportar argumentos contrastados para poder incidir en mejoras sociales tangibles ante una problemática identificada previamente a través de procesos de co-creación.',
#   'status': '',
#   'activities': 'Fiesta de la Ciencia, Bienal de Ciencia 2018, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'social',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/juegos-para-el-cambio-social',
#   'official_url': 'http://www.ub.edu/opensystems/projectes/games-for-social-change/'},
#  {'name': 'Líquenes de Barcelona',
#   'description': 'Los líquenes son organismos singulares y muy resistentes: pueden vivir sobre roca y prosperar bajo condiciones climáticas y meteorológicas extremas. Son muy sensibles al aumento de concentraciones de contaminantes, cosa que los hace unos bioindicadores excelentes, centinelas naturales de la calidad del aire. El mapa de líquenes de una ciudad refleja su calidad y permite seguir la evolución. Los ciudadanos y ciudadanas participan en el mapeo de líquenes de Barcelona trabajando con personas expertas para identificar las especies, reconocerlas y poderlas interpretar. Los datos recogidos se integran en la plataforma Natusfera, en la cual, una vez validadas, se vuelcan en la plataforma GBIF de biodiversidad global.',
#   'status': 'activo periódicamente',
#   'activities': 'Programa en los Barrios, Fiesta de la Ciencia, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/liquenes-de-barcelona',
#   'official_url': 'https://liquensdebarcelona.net/'},
#  {'name': 'Mapa Sonoro',
#   'description': 'En cada barrio, el Mapa Sonoro de Barcelona se encarga de patrimoniar sonoramente diferentes espacios públicos para poder entender analítica y científicamente aquellos sonidos que configuran las realidades acústicas de las calles, plazas y parques donde vivimos. En este proceso, la ciudadanía participa en diferentes momentos de la investigación: decide qué espacios merecen ser analizados para ser más representativos de los barrios, realiza las grabaciones sonoras con grabadoras profesionales, las anotaciones de las fuentes sonoras y recopila las sensaciones y emociones que provocan estos contextos y entornos sonoros, y los usos culturales y sociales asociados a estos espacios. ',
#   'status': 'activo',
#   'activities': 'Programa en los Barrios, Programa en las escuelas, Fiesta de la Ciencia, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'ambiental, salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/mapa-sonoro',
#   'official_url': 'http://www.bitlab.cat/projectes/mapa-sonor-de-barcelona/'},
#  {'name': 'Mosquito Alert',
#   'description': 'Mosquito Alert es un proyecto coordinado por el CREAF, el CEAB-CSIC e ICREA para la lucha contra la expansión del mosquito tigre y el mosquito de la fiebre amarilla, dos especies invasoras que pueden transmitir enfermedades globales como el zika, el dengue y el chikungunya. Con la app Mosquito Alert, cualquier persona puede notificar hallazgos de estos mosquitos y de sus lugares de cría en la vía pública enviando una foto e información relevante. Estos datos complementan el trabajo científico y de gestión de salud pública para seguir y controlar la expansión de estos mosquitos.',
#   'status': 'activo',
#   'activities': 'Programa en los Barrios, Programa en las escuelas, Fiesta de la Ciencia, Safari del ECSA 2015, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'ambiental, salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/mosquito-alert',
#   'official_url': 'http://www.mosquitoalert.com/'},
#  {'name': 'Observadores del Mar',
#   'description': 'Observadores del Mar es un portal a través del cual, personas con contacto con el mar comparten sus observaciones y experiencia relativas a fenómenos de cambio que ocurren en este medio y que son de utilidad para diversos proyectos de investigación marina. Ciudadanos y ciudadanas detectan, por ejemplo, la presencia de especies invasoras, la mortalidad masiva de organismos o la acumulación de microplástico en las playas, y lo comparten con la comunidad científica. Con los datos recibidos se generan mapas de distribución y de alerta que facilitan la gestión del medio marino.',
#   'status': 'activo',
#   'activities': 'Programa en los Barrios, Programa en las escuelas, Fiesta de la Ciencia, Safari del ECSA 2015, Bienal de Ciencia 2018, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/observadores-del-mar',
#   'official_url': 'http://www.observadorsdelmar.cat/'},
#  {'name': 'Odour Collect',
#   'description': 'OdourCollect es una aplicación gratuita a través de la cual cualquier persona puede informar de olores. La herramienta se puede utilizar como experimento de ciencia ciudadana para crear mapas de olores colaborativos basados en observaciones en cualquier lugar y en cualquier momento. La aplicación también se puede utilizar para informar de malos olores en las comunidades afectadas por estas molestias con el objetivo de crear soluciones conjuntas con todos los agentes implicados (ciudadanía, industria, autoridades locales, científicos, científicas y personas expertas en olores) para mejorar la calidad de vida de la comunidad. OdourCollect es una herramienta para empoderar a las comunidades afectadas por molestias por olores, con datos recogidos por ciudadanos y ciudadanas que son validadas por personas expertas.',
#   'status': 'activo',
#   'activities': 'Programa en las escuelas, Fiesta de la Ciencia, Bienal de Ciencia 2018, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/odour-collect',
#   'official_url': 'https://odourcollect.eu/'},
#  {'name': 'Plant*tes',
#   'description': 'Flora urbana y alergias, ¿cooperas? es un proyecto en el que las personas participantes informan de la presencia de plantas alergógenas y de su estado fenológico (presencia de flores cerradas, abiertas, frutos). El proyecto, que cuenta con la app Plant*tes para dispositivos móviles, permite informar del nivel de riesgo de alergia al polen a pie de calle. Asimismo, ayuda a mejorar la calidad de vida de las personas que padecen alergia, que pueden evitar las zonas de mayor riesgo, a la vez que permite comprender mejor la relación entre el medio ambiente y las enfermedades alérgicas.',
#   'status': 'activo',
#   'activities': 'Programa en los Barrios, Programa en las escuelas, Fiesta de la Ciencia, Estación Ciudad 2017, Bienal de Ciencia 2018, Calidoscopi 2019, Comunidad de práctica.',
#   'topic': 'ambiental, salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/planttes',
#   'official_url': 'http://www.planttes.com/'},
#  {'name': 'Ritme Natura',
#   'description': 'La fenología es la observación de los cambios estacionales en las plantas y los animales, tales como la floración, la aparición de insectos y la migración de las aves. Los cambios en los ritmos de la naturaleza dan mucha información a los científicos y científicas sobre los efectos que el cambio climático produce sobre los ecosistemas naturales, pero hacen falta series temporales largas, homogéneas, validadas y bien repartidas geográficamente por todo el territorio. A través de Ritme Natura, la ciudadanía puede participar colaborando con observaciones pera ayudar al equipo científico a estudiar los impactos del cambio climático sobre las plantas, los animales y los seres vivos en general.',
#   'status': '',
#   'activities': 'Programa en las escuelas, Fiesta de la Ciencia, Comunidad de práctica.',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/ritme-natura',
#   'official_url': 'https://ritmenatura.cat/'},
#  {'name': 'RiuNet',
#   'description': 'RiuNet es una herramienta educativa interactiva que guía a cualquier persona en el diagnóstico del estado hidrológico y ecológico de un río. Al mismo tiempo, a través de la app para dispositivos móviles, las personas usuarias proporcionan datos científicos al Grupo de Investigación Freshwater Ecology and Management (FEM) del Departamento de Biología Evolutiva, Ecología y Ciencias Ambientales de la Universitat de Barcelona.',
#   'status': 'activo',
#   'activities': 'Programa en los Barrios, Programa en las escuelas, Fiesta de la Ciencia, Bienal de Ciencia 2018, Calidoscopi 2019, Comunidad de práctica',
#   'topic': 'ambiental',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/riunet',
#   'official_url': 'http://www.ub.edu/fem/index.php/ca/inici-riunet'},
#  {'name': 'WeCount',
#   'description': 'WeCount es un proyecto para contabilizar y medir la movilidad en las ciudades. Desde el mes de junio, la iniciativa distribuye unos sensores llamados Telraam que vecinos, vecinas y comunidades ciudadanas de Madrid y Barcelona instalan en sus ventanas para recoger datos sobre cuántos coches, vehículos pesados, bicicletas y peatones pasan por su calle. La información recopilada puede consultarse en tiempo real a través de esta plataforma y, con los resultados obtenidos, se determinará de forma conjunta qué acción de alto impacto hay que tomar para mejorar la vida en las ciudades.',
#   'status': 'activo',
#   'activities': 'Comunidad de práctica',
#   'topic': 'salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/wecount',
#   'official_url': 'https://www.wecountmovilidad.eu/'},
#  {'name': 'Red de Observadores Meteorológicos',
#   'description': 'Red de Observadores Meteorológicos. El Servei Meteorològic de Catalunya creó el año 2008 esta red formada por un colectivo de personas distribuidas por el territorio catalán. Estas personas aportan información meteorológica relevante de dos maneras: en la modalidad de observación meteorológica, tomando medidas día a día y dando soporte a la caracterización diaria del tiempo, y en la modalidad de vigilancia meteorológica, aportando información visual de fenómenos destacados a tiempo real.',
#   'status': '',
#   'activities': 'Comunidad de práctica',
#   'topic': '',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/red-de-observadores-meteorologicos',
#   'official_url': 'https://www.barcelona.cat/barcelonaciencia/es/floodup'},
#  {'name': 'Citi-Sense',
#   'description': 'Citi-Sense pretende convertir a los ciudadanos y ciudadanas en miembros activos de las decisiones ambientales de Barcelona mediante la colaboración científica. Con dispositivos móviles y sensores repartidos por la ciudad, las personas participantes pueden contribuir a obtener datos sobre la calidad del aire de la ciudad que luego se transfieren a los científicos y científicas.',
#   'status': 'terminado',
#   'activities': 'Programa en los Barrios',
#   'topic': 'salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/citi-sense',
#   'official_url': 'http://www.citi-sense.eu/'},
#  {'name': 'Saca La Lengua',
#   'description': 'Saca La Lengua quiere identificar la variedad de bacterias y hongos presentes en nuestro microbioma bucal y descubrir si esta variación está condicionada por alguna característica ambiental y / o enfermedad o síndrome. Los ciudadanos y ciudadanas contribuyen en diferentes fases de la investigación como la formulación de preguntas para recoger información útil para la investigación, la donación de muestras de saliva y la condivisión de sus hábitos de vida y la priorización de los datos a analizar. Los principales resultados de la investigación están recogidos en un juego de mesa que se ha cocreado con la ciudadanía y se puede descargar gratuitamente de la web.',
#   'status': 'terminado',
#   'activities': 'Comunidad de práctica',
#   'topic': 'salud',
#   'bcn_url': 'https://www.barcelona.cat/barcelonaciencia/es/saca-la-lengua',
#   'official_url': 'http://www.sacalalengua.org/'}]

# %%
with open('BarcelonianProjects.json', 'w', encoding='utf-8') as fp:
    json.dump(lista_diccionarios, fp,  ensure_ascii=False)
